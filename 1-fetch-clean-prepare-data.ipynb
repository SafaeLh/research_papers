# %%
pip install arxiv
pip install PyPDF2

# %%
# import arxiv
import pandas as pd
import requests
# from PyPDF2 import PdfReader
import time
import re
import ast
import numpy as np

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Fetch and clean Data

# %% [markdown]
# ## Fetch papers' data from arXiv

# %% [markdown]
# Define a list of search queries related to various topics in AI and ML.

# %%
search_query_list = ['Knowledge graph', 'Natural Language Processing','Graph Neural Network', 'Attention Networks','Contrastive Learning','Transformers','Generative Adversarial Net','Computer Vision','Artificial intelligence','Knowledge Graph Embedding']

search_list = []

# Loop through each query in the search_query_list and perform a search on arXiv.
# For each query, it fetches up to 600 results sorted by relevance and appends the results to search_list.
for elem in search_query_list:
  search = arxiv.Search(
    query=elem,
    max_results=600,
    sort_by=arxiv.SortCriterion.Relevance
  )
  search_list.append(search.results())
# Out:
# <ipython-input-134-4aaea2cf327c>:11: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   search_list.append(search.results())

# %% [markdown]
# Stock arXiv data in a dictionary

# %%
# Initialize a dictionary to store information about arXiv papers, with keys for various details such as Title, Summary, 
# Published Date, Updated Date, PDF URL, DOI, Journal Reference, Primary Category, Categories, Comments, and Authors.

data_arxiv = {
    # 'Paper_ID': [],
    'Title': [],
    'Summary': [],
    'Published_Date': [],
    'Updated_Date': [],
    'PDF_URL': [],
    'DOI': [],
    'Journal_Ref': [],
    'Primary_Category': [],
    'Categories': [],
    'Comments': [],
    # 'Report_No': [],
    'Authors_arXiv': [],
}

# Iterate over each set of results from the search queries stored in search_list.
for results in search_list:
  for result in results:
  # Check if the result is not empty, then extract and append details of each paper to the data_arxiv dictionary.
    if result:
    # data_arxiv['Paper_ID'].append(result.entry_id)
      data_arxiv['Title'].append(result.title)
      data_arxiv['Summary'].append(result.summary)
      data_arxiv['Published_Date'].append(result.published)
      data_arxiv['Updated_Date'].append(result.updated)
      data_arxiv['PDF_URL'].append(result.pdf_url)
      data_arxiv['DOI'].append(result.doi if result.doi else 'N/A')
      data_arxiv['Journal_Ref'].append(result.journal_ref if result.journal_ref else 'N/A')
      data_arxiv['Primary_Category'].append(result.primary_category)
      data_arxiv['Categories'].append(', '.join(result.categories))
      data_arxiv['Comments'].append(result.comment if result.comment else 'N/A')
      # data['Report_No'].append(result.report_no if result.report_no else 'N/A')
      data_arxiv['Authors_arXiv'].append(', '.join([author.name for author in result.authors]))

      # time.sleep(2)
    else:
      continue

# %% [markdown]
# Stock arXiv data in a dataframe

# %%
df_arxiv2 = pd.DataFrame(data_arxiv)

df_arxiv2.head()
# Out:
#                                                Title  \
# 0     Knowledge Graphs: Opportunities and Challenges
# 1  Assisted Knowledge Graph Authoring: Human-Supe...
# 2  Construction and Application of Teaching Syste...
# 3  Fast Knowledge Graph Completion using Graphics...
# 4  Joint Embedding Learning of Educational Knowle...
#
#                                              Summary  \
# 0  With the explosive growth of artificial intell...
# 1  Encyclopedic knowledge graphs, such as Wikidat...
# 2  Through the combination of crowdsourcing knowl...
# 3  Knowledge graphs can be used in many areas rel...
# 4  As an efficient model for knowledge organizati...
#
#              Published_Date              Updated_Date  \
# 0 2023-03-24 12:10:42+00:00 2023-03-24 12:10:42+00:00
# 1 2024-01-15 13:51:00+00:00 2024-01-15 13:51:00+00:00
# 2 2020-10-18 14:26:10+00:00 2020-10-18 14:26:10+00:00
# 3 2023-07-22 12:00:54+00:00 2023-07-22 12:00:54+00:00
# 4 2019-11-20 09:05:11+00:00 2019-12-23 14:52:03+00:00
#
#                              PDF_URL                           DOI  \
# 0  http://arxiv.org/pdf/2303.13948v1                           N/A
# 1  http://arxiv.org/pdf/2401.07683v1       10.1145/3627508.3638340
# 2  http://arxiv.org/pdf/2010.08995v1   10.1007/978-981-15-1956-7_3
# 3  http://arxiv.org/pdf/2307.12059v1                           N/A
# 4  http://arxiv.org/pdf/1911.08776v2  10.1007/978-3-030-41099-5_12
#
#                                          Journal_Ref Primary_Category  \
# 0                                                N/A            cs.AI
# 1                                                N/A            cs.CL
# 2  4th China Conference on Knowledge Graph and Se...            cs.DB
# 3                                                N/A            cs.AI
# 4  Artificial Intelligence Supported Educational ...            cs.CL
#
#             Categories                                           Comments  \
# 0                cs.AI                       43pages, 5 figures, 3 tables
# 1                cs.CL                             accepted at CHIIR 2024
# 2  cs.DB, cs.AI, cs.CL  Number of references:15 Classification code:90...
# 3  cs.AI, cs.DB, cs.LG                                                N/A
# 4  cs.CL, cs.AI, cs.LG                                                N/A
#
#                                        Authors_arXiv
# 0  Ciyuan Peng, Feng Xia, Mehdi Naseriparsa, Fran...
# 1                         Marcel Gohsen, Benno Stein
# 2  Jinta Weng, Ying Gao, Jing Qiu, Guozhu Ding, H...
# 3          Chun-Hee Lee, Dong-oh Kang, Hwa Jeon Song
# 4  Siyu Yao, Ruijie Wang, Shen Sun, Derui Bu, Jun...

# %%
len(set(df_arxiv2["PDF_URL"]))
# Out:
# 5715

# %% [markdown]
# Remove duplicate rows in df_arxiv2 based on the 'PDF_URL' column, keeping only unique entries and storing the result in df_arxiv_dup.

# %%
df_arxiv_dup = df_arxiv2.drop_duplicates(subset='PDF_URL')

# %%
df_arxiv_dup.shape
# Out:
# (5715, 11)

# %% [markdown]
# Split the dataframe df_arxiv_dup into smaller dataframes to manage large data chunks for further processing.

# %%
df1 = df_arxiv_dup[:1000]
df2 = df_arxiv_dup[1000:2000]
df3 = df_arxiv_dup[2000:3000]
df4 = df_arxiv_dup[3000:4000]
df5 = df_arxiv_dup[4000:5000]
df6 = df_arxiv_dup[5000:]

# %% [markdown]
# Save each split dataframe to separate CSV files for easy data handling and storage

# %%
df1.to_csv('df1.csv')
df2.to_csv('df2.csv')
df3.to_csv('df3.csv')
df4.to_csv('df4.csv')
df5.to_csv('df5.csv')
df6.to_csv('df6.csv')

# %% [markdown]
# ## Fetch additional papers' details from Semantic Scholar and full paper pdf

# %% [markdown]
# Building a comprehensive dataset of research papers by merging data from a local DataFrame and external sources, enriching it with additional information like citation counts, references, full-text content, and keywords, making it suitable for further analysis or machine learning tasks.

# %% [markdown]
# Functions used in process

# %%
# Function to fetch paper details from Semantic Scholar
def fetch_from_semantic_scholar(title):

    url = f"https://api.semanticscholar.org/graph/v1/paper/search?query={title}&fields=authors,venue,fieldsOfStudy,citationCount,citations,references,referenceCount"
    response = requests.get(url)

    i=0
    while response.status_code != 200 or i<=5:
      response = requests.get(url)
      i+=1

    if response.status_code == 200:
        papers = response.json().get('data', [])
        if papers:
            return papers[0]
    return None

# Function to extract keywords from full paper
def extract_keywords(full_text):

    keywords_pattern = re.compile(r'\bKeywords\b\s*(.*)', re.IGNORECASE)
    keywords_match = keywords_pattern.search(full_text[:5000])
    keywords = 'N/A'
    if keywords_match:
        start = keywords_match.start()
        end = start + len(keywords_match.group(0))
        lines = full_text[start:].split('\n')
        keywords = lines[0]
        if len(lines) > 1:
            keywords += ' ' + lines[1]
            if 'Introduction' not in lines[2] or 'INTRODUCTION' not in lines[2]:
              keywords += ' ' + lines[2]

    return keywords

# %% [markdown]
# **The 3 codes below must be executed one time for each different DataFrame segment (df1 to df6), to ensure that all papers are processed and stored in the data dictionary.**
# *  Only the first (df1), second (df2), and sixth (df6) DataFrames are used in this code. This selection was made due to time constraints, as processing all DataFrames would take too much time.*

# %%
# The data dictionary is initialized with various keys corresponding to different attributes of research papers
data = {
    'Paper_ID': [],
    'Title': [],
    'Summary': [],
    'Published_Date': [],
    'Updated_Date': [],
    'PDF_URL': [],
    'DOI': [],
    'Journal_Ref': [],
    'Primary_Category': [],
    'Categories': [],
    'Comments': [],
    'Full_Text': [],
    'Citation_Count': [],
    # 'Citations': [],
    'References': [],
    'Venue': [],
    'Keywords': [],
    'Authors_sccho':[],
    'nbPages' : []
}

# The code iterates over each row of the specific DataFrame segment (e.g., df6) using iterrows(). 
# For each row, it appends relevant values (e.g., title, summary, DOI) from the DataFrame to the corresponding lists in the data dictionary.
for index, row in df6.iterrows():
    
    data['Title'].append(row['Title'])
    data['Summary'].append(row['Summary'])
    data['Published_Date'].append(row['Published_Date'])
    data['Updated_Date'].append(row['Updated_Date'])
    data['PDF_URL'].append(row['PDF_URL'])
    data['DOI'].append(row['DOI'])
    data['Journal_Ref'].append(row['Journal_Ref'])
    data['Primary_Category'].append(row['Primary_Category'])
    data['Categories'].append(row['Categories'])
    data['Comments'].append(row['Comments'])


    ##  The function is called with the paper's title to retrieve additional information about the paper (e.g., citation count, references, authors).
    paper_details = fetch_from_semantic_scholar(row['Title'])
    if paper_details:
        data['Paper_ID'].append(paper_details.get('paperId'))
        data['Citation_Count'].append(paper_details.get('citationCount', 0))
        # data['Citations'].append([
        #     {'citing_paper_id': citation['paperId'], 'citing_paper_title': citation['title']}
        #     for citation in paper_details.get('citations', [])
        # ])
        data['References'].append([
            {'reference_id': reference['paperId'], 'reference_title': reference['title']}
            for reference in paper_details.get('references', [])
        ])
        data['Venue'].append(paper_details.get('venue', {}))
        data['Authors_sccho'].append([
            {'authorId': author['authorId'],'name': author['name'], 'affiliation': author.get('affiliation', 'N/A')}
            for author in paper_details.get('authors', [])
        ])
    else:
        data['Paper_ID'].append('N/A')
        data['Citation_Count'].append(0)
        data['References'].append([])
        data['Venue'].append('N/A')
        data['Authors_sccho'].append([])

    ## Fetch full text from PDF URL
    pdf_url = row['PDF_URL'].replace('abs', 'pdf')
    full_text = ''
    nb_page = 0
    if pdf_url:
        try:
            response = requests.get(pdf_url, stream=True)
            if response.status_code == 200:
                with open("temp.pdf", "wb") as f:
                    f.write(response.content)
                with open("temp.pdf", "rb") as f:
                    pdf_reader = PdfReader(f)
                    nb_page = len(pdf_reader.pages)
                    for page in pdf_reader.pages:
                        full_text += page.extract_text() or ''
        except Exception as e:
            print(f"Error fetching PDF from {pdf_url}: {e}")

    ## Extract keywords from beginning of the full text 
    keywords = extract_keywords(full_text)
    data['Keywords'].append(keywords)
    data['nbPages'].append(nb_page)
    data['Full_Text'].append(full_text)

    # Sleep for 1 seconds to avoid hitting API rate limits
    time.sleep(1)
# Out:
# WARNING:PyPDF2.generic._base:FloatObject (b'0.00-47687168') invalid; use 0.0 instead

# %%
# Create a DataFrame
df = pd.DataFrame(data)

df.head()
# Out:
#                                    Paper_ID  \
# 0  8423b0efb07abbb121678556901119203308c1c3
# 1  87d3b93d74876383d1a3e603aa6e115ac0e96e37
# 2  7bb4cd36de648ca44cc390fe886ee70a4b2ad1ac
# 3  faff441c3b17abb7ff70f019dcb8b9e38cce70f6
# 4  4159c233b9c94062c25d21f3869cf6dafd6822a9
#
#                                                Title  \
# 0  Graph Entropy Guided Node Embedding Dimension ...
# 1  Individual and Structural Graph Information Bo...
# 2  Knowledge Graph Embedding using Graph Convolut...
# 3  Simple and Effective Relation-based Embedding ...
# 4  Inductive Link Prediction in Knowledge Graphs ...
#
#                                              Summary  \
# 0  Graph representation learning has achieved gre...
# 1  Out-of-distribution (OOD) graph generalization...
# 2  Knowledge graph embedding methods learn embedd...
# 3  Relational graph neural networks have garnered...
# 4  Link prediction is a crucial research area in ...
#
#               Published_Date               Updated_Date  \
# 0  2021-05-07 11:40:29+00:00  2021-08-31 08:07:41+00:00
# 1  2023-06-28 03:52:41+00:00  2023-06-28 03:52:41+00:00
# 2  2021-02-14 17:19:44+00:00  2021-02-14 17:19:44+00:00
# 3  2022-05-13 06:02:13+00:00  2022-05-13 06:02:13+00:00
# 4  2023-12-16 02:26:09+00:00  2023-12-16 02:26:09+00:00
#
#                              PDF_URL  DOI Journal_Ref Primary_Category  \
# 0  http://arxiv.org/pdf/2105.03178v5  NaN         NaN            cs.LG
# 1  http://arxiv.org/pdf/2306.15902v1  NaN         NaN            cs.LG
# 2  http://arxiv.org/pdf/2102.07200v1  NaN         NaN            cs.LG
# 3  http://arxiv.org/pdf/2205.06456v1  NaN         NaN            cs.CL
# 4  http://arxiv.org/pdf/2312.10293v1  NaN         NaN            cs.LG
#
#             Categories                                           Comments  \
# 0         cs.LG, cs.AI                                                NaN
# 1  cs.LG, cs.AI, cs.CV  Accepted by IEEE Transactions on Knowledge and...
# 2         cs.LG, cs.AI                                                NaN
# 3                cs.CL                             Accepted by IJCAI 2022
# 4                cs.LG                                                NaN
#
#                                            Full_Text  Citation_Count  \
# 0  Graph Entropy Guided Node Embedding Dimension ...              21
# 1  IEEE TRANSACTIONS ON KNOWLEDGE AND DATA ENGINE...               5
# 2  Knowledge Graph Embedding using Graph Convolut...               8
# 3  Simple and Effective Relation-based Embedding ...               8
# 4  Pre-print version\nInductive Link Prediction i...               0
#
#                                           References  \
# 0  [{'reference_id': '5ca519392bdd6b0536d1ac5a66a...
# 1  [{'reference_id': '4a3e6608cb75efdff66dc38ae97...
# 2  [{'reference_id': '3cf68c49d5745cdcbdefe6f637b...
# 3  [{'reference_id': '858e8322acf7a59c3919d354dde...
# 4  [{'reference_id': '8c720eb939259971bcb87f46c92...
#
#                                                Venue  \
# 0  International Joint Conference on Artificial I...
# 1  IEEE Transactions on Knowledge and Data Engine...
# 2                                          arXiv.org
# 3  International Joint Conference on Artificial I...
# 4                                          arXiv.org
#
#                                             Keywords  \
# 0                                                N/A
# 1                                                N/A
# 2  KEYWORDS Knowledge Graphs, Embedding, Graph At...
# 3                                                N/A
# 4                                                N/A
#
#                                        Authors_sccho
# 0  [{'authorId': '2142400413', 'name': 'Gongxu Lu...
# 1  [{'authorId': '2155557947', 'name': 'Ling Yang...
# 2  [{'authorId': '32216985', 'name': 'Nasrullah S...
# 3  [{'authorId': '2109616592', 'name': 'Huijuan W...
# 4  [{'authorId': '1390468139', 'name': 'Canlin Zh...

# %%
# Save DataFrame to CSV

df.to_csv('df6_papers.csv', encoding='utf-8-sig',  escapechar='\\', sep=',',errors='ignore')

# %% [markdown]
# ( if needed !) Function to clean text by removing non-ASCII characters.

# %%
# Function to replace non-UTF-8 characters with a placeholder
def clean_text(text):
    if isinstance(text, str):
        return ''.join(char if ord(char) < 128 else '?' for char in text)
    else:
        return text

# Clean the DataFrame, excluding columns with Timestamp objects
df_cleaned = df.applymap(clean_text)

# Save the cleaned DataFrame to CSV with specified encoding
df_cleaned.to_csv('df6_papers.csv', encoding='utf-8-sig', index=False, escapechar='\\', sep=',')

# %% [markdown]
# Load specific DataFrames from CSV files.

# %%
df1_full = pd.read_csv('df1_papers.csv', delimiter=',', index_col=0)
df2_full = pd.read_csv('df2_papers.csv', delimiter=',', index_col=0)
df6_full = pd.read_csv('df6_papers.csv', delimiter=',', index_col=0)

# %% [markdown]
# Concatenate the selected DataFrames (df1, df2, and df6) along the rows (axis=0).

# %%
df = pd.concat([df1_full,df2_full,df6_full], axis = 0)

# %% [markdown]
# Reset the index of the concatenated DataFrame, dropping the old index to maintain a clean, sequential order.

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Save the concatenated DataFrame to a CSV file named 'df1_2_6_full.csv'.

# %%
df.to_csv('df1_2_6_full.csv', encoding='utf-8-sig', index=False, escapechar='\\', sep=',')

# %% [markdown]
# ## Clean Keywords column and Extract keywords

# %%
df = pd.read_csv("df1_2_6_full.csv", index_col=0)
df.shape
# Out:
# (1706, 21)

# %% [markdown]
# The following code cleans the Keywords column of a the dataFrame (df) by removing unwanted keywords and setting specific rows to NaN if they are in the null_rows list or contain keywords that need to be excluded.

# %%
# null_rows contains the indices of rows where the 'Keywords' column either contains 'NaN' strings or where the keywords were mistakenly 
# extracted from sections like the introduction, rather than being proper keywords from the text.

null_rows = [17,21, 22, 27, 51, 59, 65, 119, 933,982,121,2135,2402,1982, 123, 126, 149, 150,2670, 153, 160, 167, 179, 188, 190, 195, 198, 207, 220, 224, 228, 233, 239, 249, 257, 282,307,319,320,329,361,380, 427, 454, 488, 514, 529, 550, 572, 592, 601, 602, 634, 641, 644, 646, 657, 663, 673, 674, 690, 703, 713, 717, 718, 739, 743, 747, 748, 751, 753, 762, 768, 791, 796, 798, 800, 810, 829, 830, 834, 838, 846, 853, 855, 862, 876, 879, 905, 930, 944, 950, 953, 957, 957, 958, 981, 984, 1017, 1021, 1022, 1027, 1051, 1059, 1065, 1119, 1121, 1123, 1126, 1149, 1150, 1153, 1160, 1167, 1179, 1188, 1190, 1195, 1198, 1207, 1220, 1224, 1228, 1233, 1239, 1257, 1282, 1307, 1319, 1320, 1329, 1354, 1361, 1380, 1427, 1454, 1488, 1529, 1550, 1571, 1572, 1592, 1601, 1634, 1646, 1657, 1663, 1673, 1674, 1690, 1703, 1706,1713, 1717, 1718, 1739, 1743, 1747, 1748, 1751, 1753, 1755, 1762, 1768, 1791, 1796, 1798, 1800, 1810, 1829, 1830, 1834, 1838, 1846, 1853, 1855, 1862, 1876, 1879, 1905, 1930, 1933, 1950, 1953, 1957, 1958, 1968, 1981, 1984, 2050, 2077, 2079, 2120, 2121, 2165, 2268, 2335, 2367, 2449, 2467, 2478, 2491, 2501, 2584, 2634, 2651, 2695]

# Keywords that need to be removed from the 'Keywords' column if found.
keywords_to_remove = [
    'Introduction', 'Email', 'Abstract', 'MOTS-CLÉS', 'DOI',
    'Corresponding', 'arXiv', 'https', 'Preprint', 'This',
    'ACM Reference Format', 'Received', 'ACMReference Format', '1','1.','*','Please', 'I. INTRODUCTION','This version','the study',
    "∗this",'∗we thank','∗Electronic', '*these'
]

keywords_to_remove = [kw.lower() for kw in keywords_to_remove]

# Function to clean the 'Keywords' column by checking for null rows and removing unwanted keywords.
def clean_keywords(keyword, index):
    if pd.isnull(keyword) or index in null_rows:
        return np.nan
    keyword_lower = keyword.lower()
    for kw in keywords_to_remove:
        if kw in keyword_lower:
            keyword_lower = keyword_lower.split(kw)[0].strip()
            if not keyword_lower:  # If keyword becomes empty, set to NaN
                return np.nan
            return keyword_lower
    return keyword

df['Keyword_semi'] = df.apply(lambda row: clean_keywords(row['Keywords'], row.name), axis=1)

# %%
df[~df["Keywords"].isna()][["Keywords","Keyword_semi"]]
# Out:
#                                                Keywords  \
# 0     Keywords: Knowledge graphs, arti
# cial intellig...
# 1     KEYWORDS Knowledge Graph Construction, Semanti...
# 2     Keywords:  Educational K nowledge Graph; learn...
# 3     Keywords Knowledge Graph Embedding ·Knowedge G...
# 4     Keywords Educational Technologies Knowledge G...
# ...                                                 ...
# 2701  Keywords : Scholarly Knowledge Graph Knowledge...
# 2706  Keywords: Event-centric knowledge graphs ·Repr...
# 2711  KEYWORDS knowledge graph completion; relation ...
# 2713  Keywords: Knowledge Representation and Reasoni...
# 2714  Keywords: Graph Embeddings AttributesKnowled...
#
#                                            Keyword_semi
# 0     Keywords: Knowledge graphs, arti
# cial intellig...
# 1     KEYWORDS Knowledge Graph Construction, Semanti...
# 2     Keywords:  Educational K nowledge Graph; learn...
# 3     keywords knowledge graph embedding ·knowedge g...
# 4     keywords educational technologies knowledge g...
# ...                                                 ...
# 2701  Keywords : Scholarly Knowledge Graph Knowledge...
# 2706  keywords: event-centric knowledge graphs ·repr...
# 2711  keywords knowledge graph completion; relation ...
# 2713  keywords: knowledge representation and reasoni...
# 2714  keywords: graph embeddings attributesknowled...
#
# [1063 rows x 2 columns]

# %%
# A little overview to check for further cleaning
df.iloc[[864, 933, 982, 1864, 1891, 1982, 2135, 2143, 2157, 2402, 2561, 2666, 2670]][["Keyword_semi"]]
# Out:
#                                            Keyword_semi
# 864   keywords: process mining ·natural language gen...
# 933                                                 NaN
# 982                                                 NaN
# 1864  keywords: process mining ·natural language gen...
# 1891  keywords: dependency distance, natural languag...
# 1982                                                NaN
# 2135                                                NaN
# 2143  keywords: artiﬁcial intelligence, deep neural ...
# 2157  keywords: quantitative causality, information ...
# 2402                                                NaN
# 2561  keywords: knowledge graph completion, tensor f...
# 2666  keywords -word embeddings; umls; convolutional...
# 2670                                                NaN

# %% [markdown]
# This regex pattern identifies and removes occurrences of the word 'keywords' (case-insensitive) followed by optional punctuation (like colons, dashes, or em dashes) from the 'Keyword_semi' column, and then trims any leading or trailing spaces from the cleaned keyword strings.

# %%
# Define a regex to Clean the keywords column
pattern = r'(?i)\bkeywords\s*[:\-—]*\s*\b'

df['Keywords_cleaned'] = df['Keyword_semi'].str.replace(pattern, '', regex=True).str.strip()

# %% [markdown]
# This code removes any occurrences of the character '1' and the letter 'i' from the 'Keywords_cleaned' column, and then filters the DataFrame to display only the non-null values from both 'Keyword_semi' and 'Keywords_cleaned' columns.

# %%
df['Keywords_cleaned'] = df['Keywords_cleaned'].str.replace('1','')
df['Keywords_cleaned'] = df['Keywords_cleaned'].str.replace('i','')
df[~df["Keywords_cleaned"].isna()][["Keyword_semi","Keywords_cleaned"]]
# Out:
#                                            Keyword_semi  \
# 0     Keywords: Knowledge graphs, arti
# cial intellig...
# 1     KEYWORDS Knowledge Graph Construction, Semanti...
# 2     Keywords:  Educational K nowledge Graph; learn...
# 3     keywords knowledge graph embedding ·knowedge g...
# 4     keywords educational technologies knowledge g...
# ...                                                 ...
# 2701  Keywords : Scholarly Knowledge Graph Knowledge...
# 2706  keywords: event-centric knowledge graphs ·repr...
# 2711  keywords knowledge graph completion; relation ...
# 2713  keywords: knowledge representation and reasoni...
# 2714  keywords: graph embeddings attributesknowled...
#
#                                        Keywords_cleaned
# 0     Knowledge graphs, art
# cal ntellgence, graph em...
# 1     Knowledge Graph Constructon, Semantc Web, Info...
# 2     Educatonal K nowledge Graph; learn ng analyss ...
# 3     knowledge graph embeddng ·knowedge graph compl...
# 4     educatonal technologes knowledge graph embedd...
# ...                                                 ...
# 2701  Scholarly Knowledge Graph Knowledge Graph Embe...
# 2706  event-centrc knowledge graphs ·representaton l...
# 2711  knowledge graph completon; relaton extrapolato...
# 2713  knowledge representaton and reasonng, robotcs,...
# 2714        graph embeddngs attrbutesknowledge graph
#
# [857 rows x 2 columns]

# %% [markdown]
# Spliting the 'Keywords_cleaned' string into a list of individual keywords based on specified delimiters (comma, semicolon, middle dot, or double space). It also removes any leading or trailing whitespace from each keyword. The resulting list is stored in a new column 'Keywords_list'.

# %%
# Define a function to split each string in the column
def split_keywords(keyword):
    if pd.isnull(keyword):
        return np.nan
    # Use regular expression to split by , ; · or double space
    split_pattern = re.compile(r',|;|·|  ')
    keywords_list = split_pattern.split(keyword)
    # Remove leading and trailing whitespace from each keyword
    keywords_list = [kw.strip() for kw in keywords_list]
    return keywords_list

df['Keywords_list'] = df['Keywords_cleaned'].apply(split_keywords)

# %%
df[~df["Keywords_cleaned"].isna()][["Keywords_cleaned","Keywords_list"]]
# Out:
#                                        Keywords_cleaned  \
# 0     Knowledge graphs, art
# cal ntellgence, graph em...
# 1     Knowledge Graph Constructon, Semantc Web, Info...
# 2     Educatonal K nowledge Graph; learn ng analyss ...
# 3     knowledge graph embeddng ·knowedge graph compl...
# 4     educatonal technologes knowledge graph embedd...
# ...                                                 ...
# 2701  Scholarly Knowledge Graph Knowledge Graph Embe...
# 2706  event-centrc knowledge graphs ·representaton l...
# 2711  knowledge graph completon; relaton extrapolato...
# 2713  knowledge representaton and reasonng, robotcs,...
# 2714        graph embeddngs attrbutesknowledge graph
#
#                                           Keywords_list
# 0     [Knowledge graphs, art
# cal ntellgence, graph e...
# 1     [Knowledge Graph Constructon, Semantc Web, Inf...
# 2     [Educatonal K nowledge Graph, learn ng analyss...
# 3     [knowledge graph embeddng, knowedge graph comp...
# 4     [educatonal technologes knowledge graph embed...
# ...                                                 ...
# 2701  [Scholarly Knowledge Graph Knowledge Graph Emb...
# 2706  [event-centrc knowledge graphs, representaton ...
# 2711  [knowledge graph completon, relaton extrapolat...
# 2713  [knowledge representaton and reasonng, robotcs...
# 2714       [graph embeddngs attrbutesknowledge graph]
#
# [857 rows x 2 columns]

# %% [markdown]
# Creating a flattened list of all keywords from the 'Keywords_list' column, by iterating through each sublist (which represents individual keyword lists) and extracting each keyword, while excluding any NaN values.

# %%
all_keywords = [item for sublist in df['Keywords_list'].dropna() for item in sublist]

# %%
all_keywords = set(all_keywords)

# %%
keywords_final = ['knowledge graph','neural-symbolic integraton','recommender system','explainable predicton','uzbek language',
                  'embedding','completion','knowledge graph reasoning','reinforcement learnng','causal graph',
                  'natural language processing','knowledge graph completion','emotional analysis','prompt-tuning','literate programmng',
                  'financial regulaton','entity retrieval','graph mining','large computing systems','human-robot interacton',
                  'probabilistic medical knowledge graph','hausa language','biomedical graph','link prediction','clustering',
                  'meta-knowledge transfer','low resource language','spatio-temporal data','reasoning','similarity join','neural networks',
                  'graph convolutional networks','ontology learning','dialogue systems','Cross-domain recommendation','language models',
                  'word similarity','knowledge enhanced recommendation','representation learning','ontologies','artificial intelligence',
                  'contrastve learnng','visualization','interface design','timestamp distribution','natural language generation',
                  'knowledge graph embeddings','neural networks','text classification','protégé', 'security data','information extraction',
                  'automatic programming','random walk','software engineering','knowledge bases','semantic query','language acquisition',
                  'meta learning','medical expert systems','large language models','generative ai','negative sampling','human language technologies',
                  'semantic web','semantic data integration','recursive neural networks','event prediction','knowledge transfer',
                  'graph summarization','dynamic graph embedding','classification','probabilistic', 'bipartite heterogeneous graph','stop words' ,
                  'bayesian networks', 'biomedical knowledge graphs','multi-task learning','language processng','time-aware knowledge graph',
                  'question answering','graph neural networks','pretrained language models','process mining','hierarchical clustering',
                  'intelligence modelling','database model', 'time series forecasting','relational learning','autonomous intelligence',
                  'collaboratve filtering','alignment relationship','systems security','explainable ai','retrieval augmentation',
                  'smart manufacturing','machine translation','turkish natural language processing','informaton theory','entity alignment',
                  'attention network','ontology embedding','word embedding','owl2vec','artificial intelligence','neo4j','lstm','chatgpt',
                  'entity linking','knowledge base question answering','transformer','entity clustering','triple embedding',
                  'graph representaton learnng','inductive knowledge graph','cyber security','reinforcement learning','machine learning',
                  'event extraction','natural language inference','social network analysis','quantum computing','kolmo gorov complexity',
                  'negative sampling','chatbot','deep learning','sentiment analysis','prediction','meta learning','interaction graph','rdf2vec',
                  'computer vision','representation learning','natural language','non-sampling machne learnng','graph reasoning','text-to-speech',
                  'pattern recognition','healthcare systems','digital marketing','translators','node embedding','deep neural networks',
                  'tensor decomposition','label classification','sql databases','stemmer','temporal knowledge graph','covid 19','text2kg',
                  'federated learning','internet of things','multi-agent systems','encoders','data science','markov model','term memory',
                  'decision making','data augmentaton','adversarial transfer learning','similarity','label propagation','visual encoding',
                  'graph augmentation','causal inference','data Annotation','retrieval augmented generation','uncertainty', 'graph kernels',
                  'named entity recognition','hyperparameter tuning','commonsense reasoning','link prediction','construction','message passing',
                  'node embedding', 'information extraction','word2vec','self-supervised learning','support vector machine','robotics',
                  'augmented llms','knowledge acquisition','text classification','unsupervised learning','tensor factorization',
                  'document classification','graph convolutional network','causality','temporal','extraction','prediction','tensor',
                  'semantic', 'language model','data extraction','question answering','query','link prediction','human-robot','interaction',
                  'graph augmentation'
                  ]

commun_keywords = [
    'Ontology', 'Semantic Web', 'Triple Store', 'Resource Description Framework', 'Linked Data', 'Entity Linking', 'Relation Extraction',
  'Graph Embedding', 'Text Mining', 'Sentiment Analysis', 'Named Entity Recognition ', 'Machine Translation', 'Text Classification',
  'Word Embedding', 'Language Modeling', 'Text Generation', 'Tokenization', 'Node Classification', 'Graph Convolutional Networks',
  'Graph Attention Networks', 'Graph Embedding', 'Graph Representation Learning', 'Link Prediction', 'Graph Clustering', 'Network Embedding',
  'Message Passing', 'Self-Attention', 'Multi-Head Attention', 'Transformer', 'Attention Mechanism', 'Sequence-to-Sequence', 'Context Vector',
  'Neural Machine Translation', 'Attention Weights', 'Scaled Dot-Product Attention', 'Self-Supervised Learning', 'Representation Learning',
  'Contrastive Loss', 'Positive Pairs', 'Negative Pairs', 'Data Augmentation', 'Embedding Space', 'Siamese Networks', 'Mutual Information',
  'Transformer Architecture', 'Encoder-Decoder', 'Self-Attention', 'Generative Pre-trained Transformer', 'Pre-training', 'Fine-Tuning', 'Sequence Modeling',
  'Attention Head', 'Generator', 'Discriminator', 'Adversarial Loss', 'Data Augmentation', 'Image Synthesis', 'Style Transfer', 'GAN', 'Latent Space', 'Conditional GANs',
  'Object Detection', 'Image Segmentation', 'Convolutional Neural Networks' , 'Image Classification', 'Feature Extraction', 'Image Recognition',
  'Face Detection', 'Image Augmentation', 'Optical Flow', 'Image Generation', 'Machine Learning', 'Deep Learning', 'Reinforcement Learning', 'Neural Networks',
  'Autonomous Systems', 'AI Applications', 'Intelligent Systems', 'AI Algorithms', 'Predictive Modeling', 'Embedding Space', 'Link Prediction',
  'Triple Embedding', 'Translational Models', 'Graph Neural Networks', 'Relational Learning', 'Knowledge Base Completion', 'Entity Embedding',
  'Relation Embedding', 'Matrix Factorization', 'Tensor Decomposition','generative adversarial network', 'graph', 'graphs', 'markov',
    'knowledge', 'language', 'neurotechnologies'
]

commun_keywords = [kw.lower() for kw in commun_keywords]

keywords_final.extend(commun_keywords)

# %%
len(set(keywords_final))
# Out:
# 262

# %%
# Clean the keywords List
keywords_final = set(keywords_final)

# %% [markdown]
# Cleaning up the DataFrame structure by Removing the 'Extracted_Keywords' column from the DataFrame 'df'

# %%
df.drop(columns=["Extracted_Keywords"], inplace=True)

# %% [markdown]
# Extracting keywords from the abstracts of papers that **do not have any keywords**.
#
# It takes an abstract and a list of keywords, checks for each keyword's presence in the abstract, and collects those that match into a set to avoid duplicates. The extracted keywords are then returned as a list. The function is applied to the 'Summary' column of the DataFrame 'df', and the results are stored in a new column named 'Extracted_Keywords'.

# %%
# Extract from the abstract of the papers with none keywords

def extract_keywords(abstract, keywords_list):
    if pd.isna(abstract):
        return []
    abstract_keywords = set()
    for keyword in keywords_list:
        if keyword.lower() in abstract.lower():
            abstract_keywords.add(keyword.lower())
    return list(abstract_keywords)

# Apply the function to the 'Abstracts' column
df['Extracted_Keywords'] = df['Summary'].apply(lambda x: extract_keywords(x, keywords_final))

# %% [markdown]
# Dropping rows from 'df' that have NaN values in the 'Paper_ID' and 'Title' columns. The index is reset to ensure a clean sequential index

# %%
df_na = df.dropna(subset=["Paper_ID"])
df_na = df_na.dropna(subset=["Title"])

df_na.reset_index(drop=True, inplace=True)

df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Paper_ID            2704 non-null   object
#  1   Title               2704 non-null   object
#  2   Summary             2704 non-null   object
#  3   Published_Date      2704 non-null   object
#  4   Updated_Date        2704 non-null   object
#  5   PDF_URL             2704 non-null   object
#  6   DOI                 328 non-null    object
#  7   Journal_Ref         254 non-null    object
#  8   Primary_Category    2704 non-null   object
#  9   Categories          2704 non-null   object
#  10  Comments            1650 non-null   object
#  11  Full_Text           2685 non-null   object
#  12  Citation_Count      2704 non-null   float64
#  13  References          2704 non-null   object
#  14  Venue               2595 non-null   object
#  15  Keywords            1059 non-null   object
#  16  Authors_sccho       2704 non-null   object
#  17  Keyword_semi        853 non-null    object
#  18  Keywords_cleaned    853 non-null    object
#  19  Keywords_list       853 non-null    object
#  20  Extracted_Keywords  2704 non-null   object
# dtypes: float64(1), object(20)
# memory usage: 443.8+ KB

# %%
df = df_na

df.columns
# Out:
# Index(['Paper_ID', 'Title', 'Summary', 'Published_Date', 'Updated_Date',
#        'PDF_URL', 'DOI', 'Journal_Ref', 'Primary_Category', 'Categories',
#        'Comments', 'Full_Text', 'Citation_Count', 'References', 'Venue',
#        'Keywords', 'Authors_sccho', 'Keyword_semi', 'Keywords_cleaned',
#        'Keywords_list', 'Extracted_Keywords'],
#       dtype='object')

# %% [markdown]
# Removing duplicate rows from the DataFrame 'df', keeping only the first occurrence of each unique value in the 'PDF_URL' column.

# %%
df.drop_duplicates(subset=['PDF_URL'], inplace=True)

# %%
df.shape
# Out:
# (1708, 21)

# %%
df[df.duplicated(subset=["Paper_ID"], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Paper_ID, Title, Summary, Published_Date, Updated_Date, PDF_URL, DOI, Journal_Ref, Primary_Category, Categories, Comments, Full_Text, Citation_Count, References, Venue, Keywords, Authors_sccho, Keyword_semi, Keywords_cleaned, Keywords_list, Extracted_Keywords]
# Index: []

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Saving the cleanded file

# %%
df.to_csv("df1_2_6_full.csv", sep=',')

# %% [markdown]
# # Preparing Data for Knowledge Graph construction

# %% [markdown]
# This section prepares data for constructing a knowledge graph based on the defined ontology.
# The ontology outlines the relationships and properties of entities involved in academic research papers, including classes such as Paper, Author, Venue, Category, and Keyword.
# Each entity is represented in its own DataFrame, capturing relevant attributes and their relationships,
# enabling the representation of academic papers and their metadata in a structured format for further analysis.
#
#
# """
# The ontology defines six main entities:
# - **Paper**: Represents academic research papers.
# - **Author**: Represents the authors of the papers.
# - **Venue**: Represents the publication venues for the papers.
# - **Category**: Represents the categories under which the papers are classified.
# - **Keyword**: Represents keywords associated with the papers.
# - **VenueType**: Represents different types of venues.
#
# Additionally, it specifies relationships between these entities, such as:
# - Papers being published in venues.
# - Authors writing papers.
# - Papers belonging to categories.
# - Papers having associated keywords.
#
# DataFrames have been created for each entity and relationship, facilitating the construction of the knowledge graph.
# """

# %% [markdown]
# ## create category_df by webscrapping https://arxiv.org/category_taxonomy

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://arxiv.org/category_taxonomy'

response = requests.get(url)

categoryID = []
categoryName = []
categoryDescription = []

# Check if the request was successful
if response.status_code == 200:
    html_content = response.content

    soup = BeautifulSoup(html_content, 'html.parser')

    title = soup.title.string
    print(f"Title of the webpage: {title}")

    divs = soup.find_all('div', class_='column is-one-fifth')
    for div in divs:
      h4 = div.find('h4')
      if h4:
        category_id = h4.text.split(' ')[0]
        category_name = h4.find('span').text.strip('()')
        category_description = div.find_next_sibling('div').find('p').text

        categoryID.append(category_id)
        categoryName.append(category_name)
        categoryDescription.append(category_description)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

category_df = pd.DataFrame({
    'categoryID': categoryID,
    'categoryName': categoryName,
    'categoryDescription': categoryDescription
})
# Out:
# Title of the webpage: Category Taxonomy

# %%
category_df.tail()
# Out:
#     categoryID       categoryName  \
# 150    stat.CO        Computation
# 151    stat.ME        Methodology
# 152    stat.ML   Machine Learning
# 153    stat.OT   Other Statistics
# 154    stat.TH  Statistics Theory
#
#                                    categoryDescription
# 150              Algorithms, Simulation, Visualization
# 151  Design, Surveys, Model Selection, Multiple Tes...
# 152  Covers machine learning papers (supervised, un...
# 153  Work in statistics that does not fit into the ...
# 154  stat.TH is an alias for math.ST. Asymptotics, ...

# %%
category_df.to_csv("category_df.csv")

# %% [markdown]
# ## Create entities and relationships entities

# %% [markdown]
# **Papers Dataframe**

# %%
paper_df = df.copy()
paper_df.head()
# Out:
#                                    Paper_ID  \
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 1  af063194baee08931f12facdffc573e4bd29c463
# 2  f2aca403781821618d7a69d98a9fbddccb236081
# 3  9921e8a2ed1d7ddaf6fdc6491d7cea321073c0b3
# 4  fb08c6d5f8fe80cfbd9efa75b710f326f4846a0f
#
#                                                Title  \
# 0     Knowledge Graphs: Opportunities and Challenges
# 1  Assisted Knowledge Graph Authoring: Human-Supe...
# 2  Construction and Application of Teaching Syste...
# 3  Fast Knowledge Graph Completion using Graphics...
# 4  Joint Embedding Learning of Educational Knowle...
#
#                                              Summary  \
# 0  With the explosive growth of artificial intell...
# 1  Encyclopedic knowledge graphs, such as Wikidat...
# 2  Through the combination of crowdsourcing knowl...
# 3  Knowledge graphs can be used in many areas rel...
# 4  As an efficient model for knowledge organizati...
#
#               Published_Date               Updated_Date  \
# 0  2023-03-24 12:10:42+00:00  2023-03-24 12:10:42+00:00
# 1  2024-01-15 13:51:00+00:00  2024-01-15 13:51:00+00:00
# 2  2020-10-18 14:26:10+00:00  2020-10-18 14:26:10+00:00
# 3  2023-07-22 12:00:54+00:00  2023-07-22 12:00:54+00:00
# 4  2019-11-20 09:05:11+00:00  2019-12-23 14:52:03+00:00
#
#                              PDF_URL                           DOI  \
# 0  http://arxiv.org/pdf/2303.13948v1                           NaN
# 1  http://arxiv.org/pdf/2401.07683v1       10.1145/3627508.3638340
# 2  http://arxiv.org/pdf/2010.08995v1   10.1007/978-981-15-1956-7_3
# 3  http://arxiv.org/pdf/2307.12059v1                           NaN
# 4  http://arxiv.org/pdf/1911.08776v2  10.1007/978-3-030-41099-5_12
#
#                                          Journal_Ref Primary_Category  \
# 0                                                NaN            cs.AI
# 1                                                NaN            cs.CL
# 2  4th China Conference on Knowledge Graph and Se...            cs.DB
# 3                                                NaN            cs.AI
# 4  Artificial Intelligence Supported Educational ...            cs.CL
#
#             Categories                                           Comments  \
# 0                cs.AI                       43pages, 5 figures, 3 tables
# 1                cs.CL                             accepted at CHIIR 2024
# 2  cs.DB, cs.AI, cs.CL  Number of references:15 Classification code:90...
# 3  cs.AI, cs.DB, cs.LG                                                NaN
# 4  cs.CL, cs.AI, cs.LG                                                NaN
#
#                                            Full_Text  Citation_Count  \
# 0  Knowledge Graphs: Opportunities and\nChallenge...            60.0
# 1  Assisted Knowledge Graph Authoring: Human-Supe...             0.0
# 2  Construction and Application of Teaching Syste...            10.0
# 3  FAST KNOWLEDGE GRAPH COMPLETION USING GRAPHICS...             0.0
# 4  Noname manuscript No.\n(will be inserted by th...             6.0
#
#                                           References  \
# 0  [{'reference_id': 'ca89c3461a35e1341c48e43aa7b...
# 1  [{'reference_id': '3c331785f7f5629563fbc4aabfe...
# 2  [{'reference_id': '2582ab7c70c9e7fcb84545944eb...
# 3  [{'reference_id': '9e712910ff1b81b6fe2a5e71515...
# 4  [{'reference_id': '697b988f8ad6337a979b9ec3475...
#
#                                                Venue  \
# 0                     Artificial Intelligence Review
# 1  Conference on Human Information Interaction an...
# 2  China Conference on Knowledge Graph and Semant...
# 3                    J. Parallel Distributed Comput.
# 4    Advances in Analytics for Learning and Teaching
#
#                                             Keywords  \
# 0  Keywords: Knowledge graphs, arti
# cial intellig...
# 1  KEYWORDS Knowledge Graph Construction, Semanti...
# 2  Keywords:  Educational K nowledge Graph; learn...
# 3  Keywords Knowledge Graph Embedding ·Knowedge G...
# 4  Keywords Educational Technologies Knowledge G...
#
#                                        Authors_sccho  \
# 0  [{'authorId': '1726114642', 'name': 'Ciyuan Pe...
# 1  [{'authorId': '22247218', 'name': 'Marcel Gohs...
# 2  [{'authorId': '1473373066', 'name': 'Jinta Wen...
# 3  [{'authorId': '2118658200', 'name': 'Chun-Hee ...
# 4  [{'authorId': '2067824542', 'name': 'Siyu Yao'...
#
#                                         Keyword_semi  \
# 0  Keywords: Knowledge graphs, arti
# cial intellig...
# 1  KEYWORDS Knowledge Graph Construction, Semanti...
# 2  Keywords:  Educational K nowledge Graph; learn...
# 3  keywords knowledge graph embedding ·knowedge g...
# 4  keywords educational technologies knowledge g...
#
#                                     Keywords_cleaned  \
# 0  Knowledge graphs, art
# cal ntellgence, graph em...
# 1  Knowledge Graph Constructon, Semantc Web, Info...
# 2  Educatonal K nowledge Graph; learn ng analyss ...
# 3  knowledge graph embeddng ·knowedge graph compl...
# 4  educatonal technologes knowledge graph embedd...
#
#                                        Keywords_list  \
# 0  [Knowledge graphs, art
# cal ntellgence, graph e...
# 1  [Knowledge Graph Constructon, Semantc Web, Inf...
# 2  [Educatonal K nowledge Graph, learn ng analyss...
# 3  [knowledge graph embeddng, knowedge graph comp...
# 4  [educatonal technologes knowledge graph embed...
#
#                                   Extracted_Keywords
# 0  [embedding, artificial intelligence, knowledge...
# 1  [knowledge graph, natural language, construction]
# 2                    [knowledge graph, construction]
# 3  [embedding, knowledge graph completion, knowle...
# 4  [embedding, knowledge graph, gan, graph embedd...

# %%
paper_df.columns
# Out:
# Index(['Paper_ID', 'Title', 'Summary', 'Published_Date', 'Updated_Date',
#        'PDF_URL', 'DOI', 'Journal_Ref', 'Primary_Category', 'Categories',
#        'Comments', 'Full_Text', 'Citation_Count', 'References', 'Venue',
#        'Keywords', 'Authors_sccho', 'Keyword_semi', 'Keywords_cleaned',
#        'Keywords_list', 'Extracted_Keywords'],
#       dtype='object')

# %%
columns_to_drop = ["Updated_Date", "Journal_Ref","Primary_Category", "Categories", "Comments", "References", "Venue","Keywords", "Authors_sccho",'Keyword_semi', 'Keywords_cleaned',
       'Keywords_list', 'Extracted_Keywords']

paper_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
paper_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Paper_ID        2704 non-null   object
#  1   Title           2704 non-null   object
#  2   Summary         2704 non-null   object
#  3   Published_Date  2704 non-null   object
#  4   PDF_URL         2704 non-null   object
#  5   DOI             328 non-null    object
#  6   Full_Text       2685 non-null   object
#  7   Citation_Count  2704 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 169.1+ KB

# %%
paper_df["yearPublication"] = pd.to_datetime(paper_df["Published_Date"]).dt.year
paper_df.head()
# Out:
#                                    Paper_ID  \
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 1  af063194baee08931f12facdffc573e4bd29c463
# 2  f2aca403781821618d7a69d98a9fbddccb236081
# 3  9921e8a2ed1d7ddaf6fdc6491d7cea321073c0b3
# 4  fb08c6d5f8fe80cfbd9efa75b710f326f4846a0f
#
#                                                Title  \
# 0     Knowledge Graphs: Opportunities and Challenges
# 1  Assisted Knowledge Graph Authoring: Human-Supe...
# 2  Construction and Application of Teaching Syste...
# 3  Fast Knowledge Graph Completion using Graphics...
# 4  Joint Embedding Learning of Educational Knowle...
#
#                                              Summary  \
# 0  With the explosive growth of artificial intell...
# 1  Encyclopedic knowledge graphs, such as Wikidat...
# 2  Through the combination of crowdsourcing knowl...
# 3  Knowledge graphs can be used in many areas rel...
# 4  As an efficient model for knowledge organizati...
#
#               Published_Date                            PDF_URL  \
# 0  2023-03-24 12:10:42+00:00  http://arxiv.org/pdf/2303.13948v1
# 1  2024-01-15 13:51:00+00:00  http://arxiv.org/pdf/2401.07683v1
# 2  2020-10-18 14:26:10+00:00  http://arxiv.org/pdf/2010.08995v1
# 3  2023-07-22 12:00:54+00:00  http://arxiv.org/pdf/2307.12059v1
# 4  2019-11-20 09:05:11+00:00  http://arxiv.org/pdf/1911.08776v2
#
#                             DOI  \
# 0                           NaN
# 1       10.1145/3627508.3638340
# 2   10.1007/978-981-15-1956-7_3
# 3                           NaN
# 4  10.1007/978-3-030-41099-5_12
#
#                                            Full_Text  Citation_Count  \
# 0  Knowledge Graphs: Opportunities and\nChallenge...            60.0
# 1  Assisted Knowledge Graph Authoring: Human-Supe...             0.0
# 2  Construction and Application of Teaching Syste...            10.0
# 3  FAST KNOWLEDGE GRAPH COMPLETION USING GRAPHICS...             0.0
# 4  Noname manuscript No.\n(will be inserted by th...             6.0
#
#    yearPublication
# 0             2023
# 1             2024
# 2             2020
# 3             2023
# 4             2019

# %%
paper_df.rename(columns={"Paper_ID": "paperID", "Title": "title", "Summary": "abstract", "Published_Date":"dateSubmission", "PDF_URL":"url", "Full_Text":"fullText", "Citation_Count":"nbCitations"}, inplace=True)

# %%
# add the columns nbPages
def add_nbPages(url):
    pdf_url = url.replace('abs', 'pdf')
    nb_page =0
    if pdf_url:
        try:
            response = requests.get(pdf_url, stream=True)
            if response.status_code == 200:
                with open("temp.pdf", "wb") as f:
                    f.write(response.content)
                with open("temp.pdf", "rb") as f:
                    pdf_reader = PdfReader(f)
                    nb_page = len(pdf_reader.pages)
        except Exception as e:
            print(f"Error fetching PDF from {pdf_url}: {e}")

    return nb_page

# %%
paper_df["nbPages"] = paper_df["url"].apply(add_nbPages)
# Out:
# WARNING:PyPDF2._reader:incorrect startxref pointer(1)
# WARNING:PyPDF2._reader:incorrect startxref pointer(1)
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xc61c for key /Rotate
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xc6d6 for key /Rotate
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xc790 for key /Rotate

# %%
paper_df.tail()
# Out:
#                                        paperID  \
# 2699  4d336e6510d96daef3339e9a4d5323af367d9ea2
# 2700  2583b76e110b76860a0f0f87c3b65d44b9fc243a
# 2701  1319080d08861fbf20ba8c6e3157223e43d7b09d
# 2702  d64befb74b871231418a0e4dd1bd2b5ae0eb9e0e
# 2703  09a416c88b9fb9b090cd82e883d46a53b4a8cece
#
#                                                   title  \
# 2699  Zero-Shot Relational Learning for Multimodal K...
# 2700  Hierarchical Aggregations for High-Dimensional...
# 2701  Table-Top Scene Analysis Using Knowledge-Super...
# 2702  A First Experiment on Including Text Literals ...
# 2703  Improving Molecule Generation and Drug Discove...
#
#                                                abstract  \
# 2699  Relational learning is an essential task in th...
# 2700  We investigate the problem of multiplex graph ...
# 2701  In this paper, we propose a probabilistic meth...
# 2702  Graph embedding models produce embedding vecto...
# 2703  Recent advancements in generative models have ...
#
#                  dateSubmission                                url  \
# 2699  2024-04-09 11:14:45+00:00  http://arxiv.org/pdf/2404.06220v1
# 2700  2023-12-28 05:39:33+00:00  http://arxiv.org/pdf/2312.16834v1
# 2701  2020-02-19 20:10:38+00:00  http://arxiv.org/pdf/2002.08417v1
# 2702  2018-07-31 11:18:18+00:00  http://arxiv.org/pdf/1807.11761v1
# 2703  2024-02-13 20:58:36+00:00  http://arxiv.org/pdf/2402.08790v1
#
#                             DOI  \
# 2699                        NaN
# 2700  10.1109/TKDE.2023.3305809
# 2701                        NaN
# 2702                        NaN
# 2703                        NaN
#
#                                                fullText  nbCitations  \
# 2699  Zero-Shot Relational Learning for Multimodal K...          0.0
# 2700  JOURNAL OF LATEX CLASS FILES, VOL. X, NO. X, M...          0.0
# 2701  arXiv:2002.08417v1  [cs.CV]  19 Feb 2020Table-...          5.0
# 2702  A First Experiment on Including Text Literals\...         12.0
# 2703  Improving Molecule Generation and Drug Discove...          0.0
#
#       yearPublication  nbPages
# 2699             2024       11
# 2700             2023       12
# 2701             2020       17
# 2702             2018        4
# 2703             2024       12

# %%
paper_df.drop_duplicates(inplace=True)

# %%
paper_df[paper_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [paperID, title, abstract, dateSubmission, url, DOI, fullText, nbCitations, yearPublication, nbPages]
# Index: []

# %%
paper_df.shape
# Out:
# (1708, 10)

# %%
paper_df.to_csv("paper_df.csv", sep=',')

# %% [markdown]
# **Author Dataframe**

# %%
authors_df = df[["Authors_sccho"]]

# %%
authors_df.head()
# Out:
#                                        Authors_sccho
# 0  [{'authorId': '1726114642', 'name': 'Ciyuan Pe...
# 1  [{'authorId': '22247218', 'name': 'Marcel Gohs...
# 2  [{'authorId': '1473373066', 'name': 'Jinta Wen...
# 3  [{'authorId': '2118658200', 'name': 'Chun-Hee ...
# 4  [{'authorId': '2067824542', 'name': 'Siyu Yao'...

# %%
# ast.literal_eval safely evaluates a string containing a Python literal or container display to convert it to a list

authors_df['Authors_sccho'] = authors_df['Authors_sccho'].apply(ast.literal_eval)

df_exploded = authors_df.explode('Authors_sccho')

author_df = pd.json_normalize(df_exploded['Authors_sccho'])

author_df.head()
# Out:
# <ipython-input-87-7a634a48d912>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   authors_df['Authors_sccho'] = authors_df['Authors_sccho'].apply(ast.literal_eval)
#      authorId               name affiliation
# 0  1726114642        Ciyuan Peng         N/A
# 1  2143633281           Feng Xia         N/A
# 2  2149932639  Mehdi Naseriparsa         N/A
# 3     2052329  Francesco Osborne         N/A
# 4    22247218      Marcel Gohsen         N/A

# %%
author_df.rename(columns={"authorId": "authorID", "name":"authorName", "affiliation":"authorAffiliation"}, inplace=True)
author_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6351 entries, 0 to 6350
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   authorID           6317 non-null   object
#  1   authorName         6350 non-null   object
#  2   authorAffiliation  6350 non-null   object
# dtypes: object(3)
# memory usage: 149.0+ KB

# %%
author_df.drop_duplicates(subset=['authorName'],inplace=True)

# %%
author_df[author_df['authorName']=='Hao Peng']
# Out:
#       authorID authorName authorAffiliation
# 43  2138443697   Hao Peng               N/A

# %%
author_df[author_df.duplicated(subset=['authorName'])]
# Out:
# Empty DataFrame
# Columns: [authorID, authorName, authorAffiliation]
# Index: []

# %%
author_df.reset_index(drop=True, inplace=True)
author_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5133 entries, 0 to 5132
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   authorID           5108 non-null   object
#  1   authorName         5132 non-null   object
#  2   authorAffiliation  5132 non-null   object
# dtypes: object(3)
# memory usage: 120.4+ KB

# %%
author_df.to_csv("author_df.csv", sep=',')

# %% [markdown]
# **Written_by Dataframe**

# %%
written_df = df[["Paper_ID", "Authors_sccho","PDF_URL"]]

# %%
written_df.shape
# Out:
# (1706, 3)

# %%
written_df.head()
# Out:
#                                    Paper_ID  \
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 1  af063194baee08931f12facdffc573e4bd29c463
# 2  f2aca403781821618d7a69d98a9fbddccb236081
# 3  9921e8a2ed1d7ddaf6fdc6491d7cea321073c0b3
# 4  fb08c6d5f8fe80cfbd9efa75b710f326f4846a0f
#
#                                        Authors_sccho  \
# 0  [{'authorId': '1726114642', 'name': 'Ciyuan Pe...
# 1  [{'authorId': '22247218', 'name': 'Marcel Gohs...
# 2  [{'authorId': '1473373066', 'name': 'Jinta Wen...
# 3  [{'authorId': '2118658200', 'name': 'Chun-Hee ...
# 4  [{'authorId': '2067824542', 'name': 'Siyu Yao'...
#
#                              PDF_URL
# 0  http://arxiv.org/pdf/2303.13948v1
# 1  http://arxiv.org/pdf/2401.07683v1
# 2  http://arxiv.org/pdf/2010.08995v1
# 3  http://arxiv.org/pdf/2307.12059v1
# 4  http://arxiv.org/pdf/1911.08776v2

# %%
written_df['Authors_sccho'] = written_df['Authors_sccho'].apply(ast.literal_eval)

# Explode the 'Authors_sccho' column to have one author per row
written_df_exploded = written_df.explode('Authors_sccho').reset_index(drop=True)

# Normalize the 'Authors_sccho' column to separate the dictionary into columns
authors_df = pd.json_normalize(written_df_exploded['Authors_sccho'])

# Combine the original 'Paper_ID' with the normalized authors DataFrame
written_by_df = pd.concat([written_df_exploded[['Paper_ID','PDF_URL']], authors_df], axis=1)

written_by_df = written_by_df[['Paper_ID','PDF_URL', 'authorId', 'name']]
# Out:
# <ipython-input-180-08cca22b4917>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   written_df['Authors_sccho'] = written_df['Authors_sccho'].apply(ast.literal_eval)

# %%
written_by_df.rename(columns={"Paper_ID": "paperID", "name":"authorName","PDF_URL":"url"}, inplace=True)
written_by_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6345 entries, 0 to 6344
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   paperID     6345 non-null   object
#  1   url         6345 non-null   object
#  2   authorId    6311 non-null   object
#  3   authorName  6344 non-null   object
# dtypes: object(4)
# memory usage: 198.4+ KB

# %%
written_by_df[written_by_df['authorName']=='Hao Peng']
# Out:
#                                        paperID  \
# 43    9ea5874d261359e287eabb735de38a8edba1e091
# 126   ef1ef85adc38356023ada0b4abc3db4d395587dd
# 3836  a5a13071e3f834ec90c0c69087b84363abc2fb38
# 5496  8423b0efb07abbb121678556901119203308c1c3
#
#                                     url    authorId authorName
# 43    http://arxiv.org/pdf/2302.05019v1  2138443697   Hao Peng
# 126   http://arxiv.org/pdf/2105.07615v2        None   Hao Peng
# 3836  http://arxiv.org/pdf/2205.01757v1  1818378366   Hao Peng
# 5496  http://arxiv.org/pdf/2105.03178v5    49349645   Hao Peng

# %%
written_by_df.drop_duplicates(subset=["url","authorName"], inplace=True)

# %%
written_by_df[written_by_df.duplicated(subset=["paperID","authorName"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [paperID, url, authorId, authorName]
# Index: []

# %%
written_by_df.reset_index(drop=True, inplace=True)
written_by_df.to_csv("written_by_df.csv", sep=',')

# %% [markdown]
# **Belongs_to Dataframe**

# %%
belongs_to_df = df[["Paper_ID", "Primary_Category"]]

# %%
belongs_to_df.rename(columns={"Paper_ID": "paperID", "Primary_Category":"categoryID"}, inplace=True)
belongs_to_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1706 entries, 0 to 1706
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   paperID     1706 non-null   object
#  1   categoryID  1706 non-null   object
# dtypes: object(2)
# memory usage: 40.0+ KB
# <ipython-input-189-feb8b1b0fba5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   belongs_to_df.rename(columns={"Paper_ID": "paperID", "Primary_Category":"categoryID"}, inplace=True)

# %%
belongs_to_df.to_csv("belongs_to_df.csv", sep=',')

# %% [markdown]
# **Cites Dataframe**

# %%
cites = df[["Paper_ID", "References"]]

# %%
cites.head(1)
# Out:
#                                    Paper_ID  \
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
#
#                                           References
# 0  [{'reference_id': 'ca89c3461a35e1341c48e43aa7b...

# %%
def test_literal_eval(val):
    try:
        ast.literal_eval(val)
        return True
    except (ValueError, SyntaxError):
        return False

# Identify problematic rows
problematic_rows = cites[~cites['References'].apply(test_literal_eval)]
problematic_rows
# Out:
#                                       Paper_ID  \
# 81    6a4717480671318c55a4ea21844f77e1567ecb0c
# 97    f68e10067596e87c16c7ba383468077f77ed8fc1
# 364   102110351b44dfa8164ab020bb98e6ba6936b7fd
# 667   9c62b72cfcb44a509af0c9401648f31c21e794e6
# 672   02773bd1d9b2c832f33de207082aeb6e98a67d22
# 796   042764240d8047b7df96fd6e3519c17076250b9b
# 875   ae2e4d847334966e3b9404f40debc8be81547c60
# 1007  eafc3160627576c2cd419c7ceb4b25ff38f94953
# 1031  b4bf49605f0c4c250c95a1da58b70b0e93a248b2
# 1045  7fdf6b191c6bb665dcf9dabce61b924e067a8a65
# 1060  aed1a0331cd586a601b0a5d40eee61cba1a4823e
# 1126  eba8c42f158f0333b77c2c4c017e6a5fd47e806a
# 1187  6a9d7124192e46d7c278021cdcef5e9dc24306a0
# 1196  bf0a6c227cc1a90421e8cdaa2bc6af77030ed1ef
# 1258  7b62e8b56e914f114c536f1d689577935352f0d3
# 1265  46be16a191060f77baa794a52849a9a85e879475
# 1334  6328d027618a1247df0780372c695d8f9a658c78
# 1335  24b8b7f638aae07491d0ddf8644505d20e17d35a
#
#                                              References
# 81    [{'reference_id': '102110351b44dfa8164ab020bb9...
# 97    [{'reference_id': '6a4717480671318c55a4ea21844...
# 364   [{'reference_id': '07679278169720ce0385a169801...
# 667   [{'reference_id': '8bb1a24840c6a31ec6bf3b88f26...
# 672   [{'reference_id': '1c6dcfbc059feededfac9163890...
# 796   [{'reference_id': '0271547a46c1aecdd69b6825597...
# 875   [{'reference_id': '9536904b4d9e10e386a71bde487...
# 1007  [{'reference_id': '44b00080c36822b83f91cbe1c13...
# 1031  [{'reference_id': '873259438b927a32db66682f346...
# 1045  [{'reference_id': 'e1d2f2a717aa03280126f87c8e5...
# 1060  [{'reference_id': '4ffb0130c2e19033a1696c32dac...
# 1126  [{'reference_id': '02499d8a24ffcc0e5f3506d81d1...
# 1187  [{'reference_id': '8dc334c177c6a4c676ac2175e6e...
# 1196  [{'reference_id': 'cf9a4a5806ff94802aa50e6ca19...
# 1258  [{'reference_id': '26d953005dd08a863c157b528bb...
# 1265  [{'reference_id': '4cd54eed55314404d7d14318d11...
# 1334  [{'reference_id': '2baec46fc05e66f2672a82c327d...
# 1335  [{'reference_id': '2baec46fc05e66f2672a82c327d...

# %%
def safe_literal_eval(val):
    try:
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        ast.Continue

# %%
cites['References'] = cites['References'].apply(safe_literal_eval)

cites_df_exploded = cites.explode('References').reset_index(drop=True)

references_df = pd.json_normalize(cites_df_exploded['References'])

cites_df = pd.concat([cites_df_exploded['Paper_ID'], references_df], axis=1)

# %%
cites_df.columns = ['citingPaperID', 'citedPaperID', 'citedPaperName']
cites_df.head()
# Out:
#                               citingPaperID  \
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 1  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 2  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 3  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 4  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
#
#                                citedPaperID  \
# 0  ca89c3461a35e1341c48e43aa7bcc4b8671c23c3
# 1  f19405b6237b988aacaa6384f68140e723d32d1b
# 2  8e5598257e1abae4c22e6834e75376940ed2d84e
# 3  0b4fe03cbc7a51d706b68a0ac6600482e54bc344
# 4  da6245620d3b68bdc2ad902e3d8dc1b5425b226f
#
#                                       citedPaperName
# 0  ScheRe: Schema Reshaping for Enhancing Knowled...
# 1  Relational Structure-Aware Knowledge Graph Rep...
# 2  Step by step: A hierarchical framework for mul...
# 3  Constructing social media links to formal lear...
# 4  Knowledge Graphs: Introduction, History and, P...

# %%
cites_df[cites_df["citingPaperID"]=='6a4717480671318c55a4ea21844f77e1567ecb0c']
# Out:
# Empty DataFrame
# Columns: [citingPaperID, citedPaperID, citedPaperName]
# Index: []

# %%
cites_df.dropna(subset=["citedPaperID"], inplace=True)

# %%
cites_df.shape
# Out:
# (66791, 3)

# %%
cites_df.reset_index(drop=True, inplace=True)
cites_df.to_csv("cites_df.csv", sep=',')

# %% [markdown]
# **Venue Dataframe**

# %%
df.columns
# Out:
# Index(['Paper_ID', 'Title', 'Summary', 'Published_Date', 'Updated_Date',
#        'PDF_URL', 'DOI', 'Journal_Ref', 'Primary_Category', 'Categories',
#        'Comments', 'Full_Text', 'Citation_Count', 'References', 'Venue',
#        'Keywords', 'Authors_sccho', 'Keyword_semi', 'Keywords_cleaned',
#        'Keywords_list', 'Extracted_Keywords'],
#       dtype='object')

# %%
venue_df = df[["Venue","Journal_Ref"]]

# %%
venue_df.shape
# Out:
# (1706, 2)

# %%
venue_df.drop_duplicates(subset=["Venue"], inplace=True)
venue_df.shape
# Out:
# <ipython-input-219-b4e0dd777090>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   venue_df.drop_duplicates(subset=["Venue"], inplace=True)
# (427, 2)

# %%
venue_df.dropna(subset=["Venue"], inplace=True)
venue_df.reset_index(drop=True, inplace=True)
venue_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Venue        426 non-null    object
#  1   Journal_Ref  86 non-null     object
# dtypes: object(2)
# memory usage: 6.8+ KB
# <ipython-input-225-7e426a7f1c28>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   venue_df.dropna(subset=["Venue"], inplace=True)

# %%
venue_df["Venue"].value_counts().reset_index()
# Out:
#                                                  Venue  count
# 0                       Artificial Intelligence Review      1
# 1                                        Biotechnology      1
# 2    The international journal of intelligence and ...      1
# 3                                             iScience      1
# 4                                           Algorithms      1
# 5                   IEEE Vehicular Technology Magazine      1
# 6                                      Artificial Life      1
# 7           IEEE Transactions on Human-Machine Systems      1
# 8                        Journal of New Music Research      1
# 9                                          EthNLP@EACL      1
# 10   International Joint Conference on Computationa...      1
# 11                IEEE Robotics and Automation Letters      1
# 12                Frontiers in Artificial Intelligence      1
# 13                       Computers in industry (Print)      1
# 14                                         FESCA@ETAPS      1
# 15    Deutsche Jahrestagung für Künstliche Intelligenz      1
# 16   APSIPA Transactions on Signal and Information ...      1
# 17                                           SUSTAINLP      1
# 18                                               SLTAT      1
# 19   Transactions of the Association for Computatio...      1
# 20   International Journal of Prognostics and Healt...      1
# 21   ACM Transactions on Interactive Intelligent Sy...      1
# 22                                   E2ECOMPVEC@ESSLLI      1
# 23                                           xxAI@ICML      1
# 24                                    The VLDB journal      1
# 25   Mexican International Conference on Artificial...      1
# 26                                               SIGAI      1
# 27   European Conference on Logics in Artificial In...      1
# 28                           Communications of the ACM      1
# 29   Artificial Intelligence, Evolutionary Computin...      1
# 30   Journal of experimental and theoretical artifi...      1
# 31   International Workshop on Soft Computing Appli...      1
# 32                                  Information Fusion      1
# 33   Aoristo. International journal of phenomenolog...      1
# 34   Journal of Artificial Intelligence and Conscio...      1
# 35                                  Electronic Markets      1
# 36   2019 Conference on Cognitive Computational Neu...      1
# 37                               Robotics Auton. Syst.      1
# 38             2021 IEEE World AI IoT Congress (AIIoT)      1
# 39                                  Minds and Machines      1
# 40           IEEE Communications Surveys and Tutorials      1
# 41                                   Health technology      1
# 42                                Traitement du signal      1
# 43      ACM Journal on Computing and Cultural Heritage      1
# 44   Conference on Fairness, Accountability and Tra...      1
# 45                                             Futures      1
# 46                    Swiss Conference on Data Science      1
# 47                                         SafeAI@AAAI      1
# 48                      Int. J. Comput. Games Technol.      1
# 49                                  Front. Neurorobot.      1
# 50                                                ARES      1
# 51                     Applied Artificial Intelligence      1
# 52   2023 9th International Conference on Web Resea...      1
# 53   International Journal for Research in Applied ...      1
# 54   IEEE International Geoscience and Remote Sensi...      1
# 55   Computational Linguistics and Intellectual Tec...      1
# 56   BlackboxNLP Workshop on Analyzing and Interpre...      1
# 57                                            BANGLALP      1
# 58                                              ALTNLP      1
# 59   Workshop on Balto-Slavic Natural Language Proc...      1
# 60                                    Computer Science      1
# 61   International Conference on Machine Learning a...      1
# 62   International Conference on Software Engineeri...      1
# 63                                             HUMEVAL      1
# 64            Theory and Practice of Logic Programming      1
# 65   International Conference on Natural Language P...      1
# 66   The 6th International Conference on Soft Compu...      1
# 67   International Conference on Principles of Know...      1
# 68   Finite-State Methods and Natural Language Proc...      1
# 69                                                 ACT      1
# 70       International Workshop on Semantic Evaluation      1
# 71                                             LORESMT      1
# 72                                              HCINLP      1
# 73                                          PRIVATENLP      1
# 74   2017 Pattern Recognition Association of South ...      1
# 75                                      JEPTALNRECITAL      1
# 76            Machines, Computations, and Universality      1
# 77   IEEE International Conference on Formal Engine...      1
# 78   2021 IEEE/CVF Conference on Computer Vision an...      1
# 79    International Conference on Software Engineering      1
# 80   China National Conference on Chinese Computati...      1
# 81   2019 Artificial Intelligence for Transforming ...      1
# 82   International Conference on Computational Proc...      1
# 83                         Nature Machine Intelligence      1
# 84                                         Interspeech      1
# 85   Romanian Conference on Human-Computer Interaction      1
# 86   Conference on Computational Natural Language L...      1
# 87   IFIP TC13 International Conference on Human-Co...      1
# 88                         Pattern Recognition Letters      1
# 89                           Multilingual Facilitation      1
# 90                                         Rep4NLP@ACL      1
# 91   International Conference on Advances in ICT fo...      1
# 92                                   Natural Computing      1
# 93                                AAAI Spring Symposia      1
# 94      Applied Natural Language Processing Conference      1
# 95                                    Applied Sciences      1
# 96                   Language Resources and Evaluation      1
# 97   International Workshop on Trustworthy AI - Int...      1
# 98      Recent Advances in Natural Language Processing      1
# 99             Lecture Notes in Electrical Engineering      1
# 100                BigData Congress [Services Society]      1
# 101                                           TRUSTNLP      1
# 102                                               Fire      1
# 103      Clinical Natural Language Processing Workshop      1
# 104                                          Visual ..      1
# 105  IEEE Transactions on Cognitive and Development...      1
# 106  Conference on Uncertainty in Artificial Intell...      1
# 107  Conference on Human Information Interaction an...      1
# 108          International Conference on Big Knowledge      1
# 109    Journal of Computational Science and Technology      1
# 110                              Cognitive Computation      1
# 111                                          AKBC@NIPS      1
# 112  2018 IEEE/CVF Conference on Computer Vision an...      1
# 113  International Conference on Algorithmic Learni...      1
# 114  IEEE International Joint Conference on Neural ...      1
# 115  IEEE Transactions on Computational Social Systems      1
# 116  ACM Transactions on Knowledge Discovery from Data      1
# 117  International Workshop and International Works...      1
# 118         Biomedical Circuits and Systems Conference      1
# 119  IEEE International Conference on Tools with Ar...      1
# 120                                PKDD/ECML Workshops      1
# 121                      Advanced Quantum Technologies      1
# 122  2019 IEEE/CVF International Conference on Comp...      1
# 123  Journal of King Saud University: Computer and ...      1
# 124                                Semdeep/NLIWoD@ISWC      1
# 125                                  Big Data Research      1
# 126                              Proc. ACM Manag. Data      1
# 127                                                SDM      1
# 128                                        DL4KGS@ESWC      1
# 129  IEEE Transactions on Pattern Analysis and Mach...      1
# 130                               Information Sciences      1
# 131                                              WIESP      1
# 132                                  Physical Review E      1
# 133  International Conference on Advanced Data Mini...      1
# 134                            Artif. Intell. Medicine      1
# 135  Conference on Artificial Intelligence in Medic...      1
# 136              IEEE Transactions on Image Processing      1
# 137      Electronic Commerce Research and Applications      1
# 138  International Conference on Service Oriented C...      1
# 139                                       SemDeep@IWCS      1
# 140                                           SDU@AAAI      1
# 141  Pacific-Asia Conference on Knowledge Discovery...      1
# 142                                      AEQUITAS@ECAI      1
# 143                                        DALI@MICCAI      1
# 144  International Conference on Artificial Neural ...      1
# 145  International Conference of the Italian Associ...      1
# 146          Conference on Natural Language Processing      1
# 147    International Conference on Pattern Recognition      1
# 148                                         DL4KG@ESWC      1
# 149                                             LOG IN      1
# 150                                    ICDAR Workshops      1
# 151  International Joint Conference on Natural Lang...      1
# 152     European Conference on Artificial Intelligence      1
# 153                          Machine-mediated learning      1
# 154                Data mining and knowledge discovery      1
# 155                                  EuroMLSys@EuroSys      1
# 156                                   DART/FAIR@MICCAI      1
# 157  International Symposium on Intelligent Data An...      1
# 158                                             FINNLP      1
# 159                                EDBT/ICDT Workshops      1
# 160  IEEE Transactions on Visualization and Compute...      1
# 161                                Journal of Big Data      1
# 162                      Journal of engineering design      1
# 163  2022 IEEE 30th International Requirements Engi...      1
# 164                                    Future Internet      1
# 165             Neuro-Symbolic Artificial Intelligence      1
# 166  Proceedings of the 1st International Conferenc...      1
# 167     AAAI/ACM Conference on AI, Ethics, and Society      1
# 168         Journal of Artificial General Intelligence      1
# 169                                     The biochemist      1
# 170   Latin American Symposium on Circuits and Systems      1
# 171                                           Synthese      1
# 172  International Conference on Artificial Intelli...      1
# 173        ACM Conference on Economics and Computation      1
# 174  Proceedings of the Thirtieth International Joi...      1
# 175  2021 IEEE International Conference on Artifici...      1
# 176   Journal of Information Security and Applications      1
# 177                        Annals of Surgical Oncology      1
# 178  Proceedings of the 2019 International Conferen...      1
# 179                                               NAIS      1
# 180                       Serdica Journal of Computing      1
# 181  International Conference on Information Techno...      1
# 182  Artificial Intelligence and Interactive Digita...      1
# 183          IEEE Congress on Evolutionary Computation      1
# 184  International Workshop on Artificial Intellige...      1
# 185                                    The AI Magazine      1
# 186                    Teorie vědy / Theory of Science      1
# 187  International Conference on Automated Software...      1
# 188                                 IEEE design & test      1
# 189                                     AISafety@IJCAI      1
# 190  International Workshop on Neural-Symbolic Lear...      1
# 191                                       Algorithmica      1
# 192  ACM SIGACT-SIGMOD-SIGART Symposium on Principl...      1
# 193                      Frontiers of Computer Science      1
# 194                      Scandinavian Conference on AI      1
# 195  International Journal of Geographical Informat...      1
# 196    Journal of Vibration Engineering & Technologies      1
# 197     International Journal of Approximate Reasoning      1
# 198  Australasian Conference on Artificial Intellig...      1
# 199                                        Measurement      1
# 200                                  IFAC-PapersOnLine      1
# 201  IIAI International Conference on Advanced Appl...      1
# 202                                 We Will Show Them!      1
# 203  Artificial Intelligence, Soft Computing and Ap...      1
# 204  EUROMICRO Conference on Software Engineering a...      1
# 205                                            Cancers      1
# 206                            Survey of ophthalmology      1
# 207    Frontiers in Applied Mathematics and Statistics      1
# 208  Sixth International Conference of Information ...      1
# 209                              Intelligent Computing      1
# 210                     Innovation (Cambridge (Mass.))      1
# 211                                      Reasoning Web      1
# 212                                               RAIL      1
# 213  2020 1st International Conference on Big Data ...      1
# 214                                            DECLARE      1
# 215  2020 IEEE 33rd International Symposium on Comp...      1
# 216           ACM Transactions on Privacy and Security      1
# 217                                     SeWeBMeDA@ESWC      1
# 218  International Conference Algebras, graphs and ...      1
# 219        IET Generation, Transmission & Distribution      1
# 220                                         Bioinform.      1
# 221                                          NAACL-HLT      1
# 222                         Mathematics and Statistics      1
# 223  AAAI Spring Symposium Combining Machine Learni...      1
# 224                Asian Conference on Computer Vision      1
# 225                                              NLRSE      1
# 226  Proceedings of the ACM on Interactive Mobile W...      1
# 227                                     ACM Multimedia      1
# 228  IEEE transactions on intelligent transportatio...      1
# 229  2023 IEEE 19th International Conference on Aut...      1
# 230       International Conference on Semantic Systems      1
# 231                                           Findings      1
# 232                                       Semantic Web      1
# 233  International Conference on Artificial Intelli...      1
# 234                  Pacific Symposium on Biocomputing      1
# 235  International Conference on Language, Data, an...      1
# 236  Workshop on Knowledge Extraction and Integrati...      1
# 237  Proceedings of the Fifteenth Workshop on Graph...      1
# 238                                               TGDK      1
# 239  International Conference on Computer Supported...      1
# 240               Industrial Conference on Data Mining      1
# 241       Pattern Recognition and Machine Intelligence      1
# 242  2019 IEEE Innovative Smart Grid Technologies -...      1
# 243                                      Cybersecurity      1
# 244  2021 IEEE International Conference on Big Data...      1
# 245                                          KGCW@ESWC      1
# 246                            Artificial Intelligence      1
# 247  AMIA ... Annual Symposium proceedings. AMIA Sy...      1
# 248         International Workshop on the Semantic Web      1
# 249                  Journal of Biomedical Informatics      1
# 250                                     Neurocomputing      1
# 251            ACM Transactions on Information Systems      1
# 252  International Conference on Human Factors in C...      1
# 253                                          ECML/PKDD      1
# 254            Computer Vision and Pattern Recognition      1
# 255                                               AACL      1
# 256           Journal of ICT Research and Applications      1
# 257  2020 IEEE International Conference on Big Data...      1
# 258  IEEE International Conference on Acoustics, Sp...      1
# 259  International Conference on Database Systems f...      1
# 260                                        QuWeDa@ISWC      1
# 261       IEEE Transactions on Artificial Intelligence      1
# 262                           JMIR Medical Informatics      1
# 263        Intelligent Automation &amp; Soft Computing      1
# 264                    IEEE transactions on multimedia      1
# 265  Workshop on Graph-based Methods for Natural La...      1
# 266  International Conference on Principles of Dist...      1
# 267  International Conference on Theory and Practic...      1
# 268                                  SIGMOD Conference      1
# 269  International Conference on Computing, Network...      1
# 270                                 The Web Conference      1
# 271  International Conference on Artificial Intelli...      1
# 272  International Conference on Asian Digital Libr...      1
# 273  Conference on Automated Knowledge Base Constru...      1
# 274                            Knowledge-Based Systems      1
# 275              ACM Transactions on Quantum Computing      1
# 276  International Conference on Information and Kn...      1
# 277  Annual International ACM SIGIR Conference on R...      1
# 278                           Journal of Web Semantics      1
# 279                                            AI Open      1
# 280  Knowledge Graphs for eXplainable Artificial In...      1
# 281  Conference on Empirical Methods in Natural Lan...      1
# 282  Conference of the European Chapter of the Asso...      1
# 283  IEEE Transactions on Knowledge and Data Engine...      1
# 284                                               IPMV      1
# 285                              ACM Computing Surveys      1
# 286  North American Chapter of the Association for ...      1
# 287  IEEE International Conference on Data Engineering      1
# 288                                             Fusion      1
# 289                                          arXiv.org      1
# 290    Advances in Analytics for Learning and Teaching      1
# 291                    J. Parallel Distributed Comput.      1
# 292  China Conference on Knowledge Graph and Semant...      1
# 293       International Conference on Machine Learning      1
# 294  International Joint Conference on Artificial I...      1
# 295  International Conference on Industrial, Engine...      1
# 296  Workshop on Biomedical Natural Language Proces...      1
# 297  International Conference on Language Resources...      1
# 298                                           Patterns      1
# 299                   Extended Semantic Web Conference      1
# 300                                         Trans. GIS      1
# 301  Journées Francophones d'Ingénierie des Connais...      1
# 302  Iberoamerican Conference on Knowledge Graphs a...      1
# 303                                              CCGPK      1
# 304  Annual Meeting of the Association for Computat...      1
# 305                                   SumPre-HSWI@ESWC      1
# 306  International Conference on Data Science and A...      1
# 307                                     Softw. Impacts      1
# 308         AAAI Conference on Artificial Intelligence      1
# 309                                              IJCKG      1
# 310                Knowledge Discovery and Data Mining      1
# 311   IEEE International Conference on Computer Vision      1
# 312  IEEE Transactions on Neural Networks and Learn...      1
# 313                  Knowledge and Information Systems      1
# 314                                            STARSEM      1
# 315                   Microprocessors and microsystems      1
# 316        IEEE Power & Energy Society General Meeting      1
# 317                           Data-Centric Engineering      1
# 318  International Conference on Computational Ling...      1
# 319  IEEE/RJS International Conference on Intellige...      1
# 320        Workshop on Representation Learning for NLP      1
# 321  Journal of Computing and Information Science i...      1
# 322                                        iConference      1
# 323                     Information Processing Letters      1
# 324                                           CAPNS@QI      1
# 325         Research Challenges in Information Science      1
# 326                       Data & Knowledge Engineering      1
# 327  International Conference on Natural Language a...      1
# 328        Journal of Artificial Intelligence Research      1
# 329  International Conference on Database and Exper...      1
# 330                                    OTM Conferences      1
# 331  Pacific Asia Conference on Language, Informati...      1
# 332  International Conferences on Artificial Intell...      1
# 333     Nordic Conference of Computational Linguistics      1
# 334  International Conference on Intelligent Data S...      1
# 335                                    Molecular Omics      1
# 336                           Trans. Mach. Learn. Res.      1
# 337                                                Sai      1
# 338                                        LASCAR@ESWC      1
# 339                             CHI Extended Abstracts      1
# 340                                         DL4KG@ISWC      1
# 341              Encyclopedia of Big Data Technologies      1
# 342  Natural Language Processing and Chinese Computing      1
# 343                  Int. J. Inf. Manag. Data Insights      1
# 344                                 BMC Bioinformatics      1
# 345                    Artificial General Intelligence      1
# 346  International Conference on Mathematics and Co...      1
# 347                                             NLPOSS      1
# 348                          Computational Linguistics      1
# 349  Symposium on Symbolic and Numeric Algorithms f...      1
# 350  International Workshop/Conference on Parsing T...      1
# 351  International Conference on Intelligent and Ad...      1
# 352                Information Processing & Management      1
# 353  International Journal on Natural Language Comp...      1
# 354  2023 IEEE 8th International Conference for Con...      1
# 355  International Conference on Agents and Artific...      1
# 356                                               ICON      1
# 357                                    BlackboxNLP@ACL      1
# 358                                          AfricaNLP      1
# 359  Workshop on Spoken Language Technologies for U...      1
# 360                    Social Science Research Network      1
# 361     IEEE International Conference on Fuzzy Systems      1
# 362                                JSAI-isAI Workshops      1
# 363                               Drug Discovery Today      1
# 364                            Physics of Life Reviews      1
# 365  Conference on Theory and Practice of Informati...      1
# 366         Journal of Logic, Language and Information      1
# 367                                   JEP/TALN/RECITAL      1
# 368                  Multimedia tools and applications      1
# 369                        Controlled Natural Language      1
# 370                                              WINLP      1
# 371           Learning for Natural Language Processing      1
# 372           Proceedings of the AAAI Symposium Series      1
# 373                            Proceedings of the IEEE      1
# 374  International Conference on Wirtschaftsinformatik      1
# 375                  Proceedings of the VLDB Endowment      1
# 376     ACM/IEEE Joint Conference on Digital Libraries      1
# 377  IEEE International Conference on Software Anal...      1
# 378  International Conference on Advances in Social...      1
# 379                    Journal of Biomedical Semantics      1
# 380                              ACM Trans. Inf. Syst.      1
# 381                                         SAFA@COMMA      1
# 382                                           PLoS ONE      1
# 383                        SIGMOD Conference Companion      1
# 384                                               SUKI      1
# 385  International Journal of Image Graphics and Si...      1
# 386                         Web Search and Data Mining      1
# 387   International Conference on Multimedia Retrieval      1
# 388       International Journal of Production Research      1
# 389      International Conference on Knowledge Capture      1
# 390  International Conference on Knowledge and Syst...      1
# 391              Neural Information Processing Systems      1
# 392  International Conference on Learning Represent...      1
# 393       European Conference on Information Retrieval      1
# 394                                             NEWSUM      1
# 395  IEEE International Conference on Bioinformatic...      1
# 396  International Conference on Cloud Computing an...      1
# 397         ACM Conference on Hypertext & Social Media      1
# 398                                   BlockSW/CKG@ISWC      1
# 399  International Conference on Neural Information...      1
# 400                  British Machine Vision Conference      1
# 401             European Conference on Computer Vision      1
# 402      2021 IEEE Intelligent Vehicles Symposium (IV)      1
# 403       International Journal of Intelligent Systems      1
# 404  International Joint Conference on Knowledge Di...      1
# 405                       J. Assoc. Inf. Sci. Technol.      1
# 406           Annual Review of Biomedical Data Science      1
# 407      Journal of Industrial Information Integration      1
# 408  International Conference on Information System...      1
# 409                                  TEXT2KG/BiKE@ESWC      1
# 410                                 Scientific Reports      1
# 411                                        IEEE Access      1
# 412                  Involve. A Journal of Mathematics      1
# 413               Journal of machine learning research      1
# 414                                     RecSys Posters      1
# 415  2021 IEEE International Conference on Consumer...      1
# 416                    NeurIPS Datasets and Benchmarks      1
# 417  Conference on Computer Science and Information...      1
# 418                            Found. Trends Databases      1
# 419          Machine Learning and Knowledge Extraction      1
# 420  2017 IEEE International Conference on Big Data...      1
# 421  CAAI International Conference on Artificial In...      1
# 422                      Applied intelligence (Boston)      1
# 423                                          WorldCIST      1
# 424  IEEE Workshop/Winter Conference on Application...      1
# 425  2021 IEEE 23rd Int Conf on High Performance Co...      1

# %%
def update_type(row):
    if 'journal' in row['Venue'].lower() or 'transaction' in row['Venue'].lower():
        return 'journal'
    elif 'conference' in row['Venue'].lower():
        return 'conference'
    elif 'workshop' in row['Venue'].lower():
        return 'workshop'
    else:
        if row['venueType'] == 'journal':
          return 'conference'
        else:
          return 'journal'

# Apply the function to the DataFrame
venue_df['venueType'] = venue_df.apply(update_type, axis=1)
# Out:
# <ipython-input-240-9223e5e48d4d>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   venue_df['venueType'] = venue_df.apply(update_type, axis=1)

# %%
venue_df
# Out:
#                                                  Venue  \
# 0                       Artificial Intelligence Review
# 1    Conference on Human Information Interaction an...
# 2    China Conference on Knowledge Graph and Semant...
# 3                      J. Parallel Distributed Comput.
# 4      Advances in Analytics for Learning and Teaching
# 5                                            arXiv.org
# 6                                               Fusion
# 7    IEEE International Conference on Data Engineering
# 8    North American Chapter of the Association for ...
# 9                                ACM Computing Surveys
# 10                                                IPMV
# 11   IEEE Transactions on Knowledge and Data Engine...
# 12   Conference of the European Chapter of the Asso...
# 13   Conference on Empirical Methods in Natural Lan...
# 14   Knowledge Graphs for eXplainable Artificial In...
# 15                                             AI Open
# 16                            Journal of Web Semantics
# 17   Annual International ACM SIGIR Conference on R...
# 18   International Conference on Information and Kn...
# 19               ACM Transactions on Quantum Computing
# 20                             Knowledge-Based Systems
# 21   Conference on Automated Knowledge Base Constru...
# 22   International Conference on Asian Digital Libr...
# 23   International Conference on Artificial Intelli...
# 24                                  The Web Conference
# 25        International Conference on Machine Learning
# 26   International Joint Conference on Artificial I...
# 27   International Conference on Industrial, Engine...
# 28          AAAI Conference on Artificial Intelligence
# 29   International Conference on Computational Ling...
# 30                            Data-Centric Engineering
# 31         IEEE Power & Energy Society General Meeting
# 32                    Microprocessors and microsystems
# 33                                             STARSEM
# 34                   Knowledge and Information Systems
# 35   IEEE Transactions on Neural Networks and Learn...
# 36    IEEE International Conference on Computer Vision
# 37                 Knowledge Discovery and Data Mining
# 38                                               IJCKG
# 39                                      Softw. Impacts
# 40   Workshop on Biomedical Natural Language Proces...
# 41   International Conference on Data Science and A...
# 42                                    SumPre-HSWI@ESWC
# 43   Annual Meeting of the Association for Computat...
# 44                                               CCGPK
# 45   Iberoamerican Conference on Knowledge Graphs a...
# 46   Journées Francophones d'Ingénierie des Connais...
# 47                                          Trans. GIS
# 48                    Extended Semantic Web Conference
# 49                                            Patterns
# 50   International Conference on Language Resources...
# 51   International Conference on Computing, Network...
# 52                                   SIGMOD Conference
# 53   International Conference on Theory and Practic...
# 54   International Conference on Principles of Dist...
# 55                                                TGDK
# 56   Proceedings of the Fifteenth Workshop on Graph...
# 57   Workshop on Knowledge Extraction and Integrati...
# 58   International Conference on Language, Data, an...
# 59                   Pacific Symposium on Biocomputing
# 60   International Conference on Artificial Intelli...
# 61                                        Semantic Web
# 62                                            Findings
# 63        International Conference on Semantic Systems
# 64   2023 IEEE 19th International Conference on Aut...
# 65   IEEE transactions on intelligent transportatio...
# 66                                      ACM Multimedia
# 67   Proceedings of the ACM on Interactive Mobile W...
# 68                                               NLRSE
# 69                 Asian Conference on Computer Vision
# 70   AAAI Spring Symposium Combining Machine Learni...
# 71                          Mathematics and Statistics
# 72                                           NAACL-HLT
# 73                                          Bioinform.
# 74         IET Generation, Transmission & Distribution
# 75   International Conference Algebras, graphs and ...
# 76                                      SeWeBMeDA@ESWC
# 77            ACM Transactions on Privacy and Security
# 78   International Conference on Computer Supported...
# 79   2020 IEEE 33rd International Symposium on Comp...
# 80                Industrial Conference on Data Mining
# 81   2019 IEEE Innovative Smart Grid Technologies -...
# 82   Workshop on Graph-based Methods for Natural La...
# 83                     IEEE transactions on multimedia
# 84         Intelligent Automation &amp; Soft Computing
# 85                            JMIR Medical Informatics
# 86        IEEE Transactions on Artificial Intelligence
# 87                                         QuWeDa@ISWC
# 88   International Conference on Database Systems f...
# 89   IEEE International Conference on Acoustics, Sp...
# 90   2020 IEEE International Conference on Big Data...
# 91            Journal of ICT Research and Applications
# 92                                                AACL
# 93             Computer Vision and Pattern Recognition
# 94                                           ECML/PKDD
# 95   International Conference on Human Factors in C...
# 96             ACM Transactions on Information Systems
# 97                                      Neurocomputing
# 98                   Journal of Biomedical Informatics
# 99          International Workshop on the Semantic Web
# 100  AMIA ... Annual Symposium proceedings. AMIA Sy...
# 101                            Artificial Intelligence
# 102                                          KGCW@ESWC
# 103  2021 IEEE International Conference on Big Data...
# 104                                      Cybersecurity
# 105  IEEE/RJS International Conference on Intellige...
# 106        Workshop on Representation Learning for NLP
# 107  Journal of Computing and Information Science i...
# 108  International Conference on Wirtschaftsinformatik
# 109                                   BlockSW/CKG@ISWC
# 110         ACM Conference on Hypertext & Social Media
# 111  International Conference on Cloud Computing an...
# 112  IEEE International Conference on Bioinformatic...
# 113                                             NEWSUM
# 114       European Conference on Information Retrieval
# 115  International Conference on Learning Represent...
# 116              Neural Information Processing Systems
# 117  International Conference on Knowledge and Syst...
# 118      International Conference on Knowledge Capture
# 119       International Journal of Production Research
# 120   International Conference on Multimedia Retrieval
# 121                         Web Search and Data Mining
# 122  International Journal of Image Graphics and Si...
# 123                                               SUKI
# 124                        SIGMOD Conference Companion
# 125                                           PLoS ONE
# 126                                         SAFA@COMMA
# 127                              ACM Trans. Inf. Syst.
# 128                    Journal of Biomedical Semantics
# 129  International Conference on Advances in Social...
# 130  IEEE International Conference on Software Anal...
# 131     ACM/IEEE Joint Conference on Digital Libraries
# 132  International Conference on Neural Information...
# 133                  British Machine Vision Conference
# 134             European Conference on Computer Vision
# 135                                     RecSys Posters
# 136  IEEE Workshop/Winter Conference on Application...
# 137                                          WorldCIST
# 138                      Applied intelligence (Boston)
# 139  CAAI International Conference on Artificial In...
# 140  2017 IEEE International Conference on Big Data...
# 141          Machine Learning and Knowledge Extraction
# 142                            Found. Trends Databases
# 143  Conference on Computer Science and Information...
# 144                    NeurIPS Datasets and Benchmarks
# 145  2021 IEEE International Conference on Consumer...
# 146               Journal of machine learning research
# 147      2021 IEEE Intelligent Vehicles Symposium (IV)
# 148                  Involve. A Journal of Mathematics
# 149                                        IEEE Access
# 150                                 Scientific Reports
# 151                                  TEXT2KG/BiKE@ESWC
# 152  International Conference on Information System...
# 153      Journal of Industrial Information Integration
# 154           Annual Review of Biomedical Data Science
# 155                       J. Assoc. Inf. Sci. Technol.
# 156  International Joint Conference on Knowledge Di...
# 157       International Journal of Intelligent Systems
# 158                  Proceedings of the VLDB Endowment
# 159                            Proceedings of the IEEE
# 160                                        iConference
# 161           Proceedings of the AAAI Symposium Series
# 162                    Artificial General Intelligence
# 163                                 BMC Bioinformatics
# 164                  Int. J. Inf. Manag. Data Insights
# 165  Natural Language Processing and Chinese Computing
# 166              Encyclopedia of Big Data Technologies
# 167                                         DL4KG@ISWC
# 168                             CHI Extended Abstracts
# 169                                        LASCAR@ESWC
# 170                                                Sai
# 171                           Trans. Mach. Learn. Res.
# 172                                    Molecular Omics
# 173  International Conference on Intelligent Data S...
# 174     Nordic Conference of Computational Linguistics
# 175  International Conferences on Artificial Intell...
# 176  Pacific Asia Conference on Language, Informati...
# 177                                    OTM Conferences
# 178  International Conference on Database and Exper...
# 179        Journal of Artificial Intelligence Research
# 180  International Conference on Natural Language a...
# 181                       Data & Knowledge Engineering
# 182         Research Challenges in Information Science
# 183                                           CAPNS@QI
# 184                     Information Processing Letters
# 185  International Conference on Mathematics and Co...
# 186                                             NLPOSS
# 187                          Computational Linguistics
# 188     IEEE International Conference on Fuzzy Systems
# 189           Learning for Natural Language Processing
# 190                                              WINLP
# 191                        Controlled Natural Language
# 192                  Multimedia tools and applications
# 193                                   JEP/TALN/RECITAL
# 194         Journal of Logic, Language and Information
# 195  Conference on Theory and Practice of Informati...
# 196                            Physics of Life Reviews
# 197                               Drug Discovery Today
# 198                                JSAI-isAI Workshops
# 199                    Social Science Research Network
# 200  Symposium on Symbolic and Numeric Algorithms f...
# 201  Workshop on Spoken Language Technologies for U...
# 202                                          AfricaNLP
# 203                                    BlackboxNLP@ACL
# 204                                               ICON
# 205  International Conference on Agents and Artific...
# 206  2023 IEEE 8th International Conference for Con...
# 207  International Journal on Natural Language Comp...
# 208                Information Processing & Management
# 209  International Conference on Intelligent and Ad...
# 210  International Workshop/Conference on Parsing T...
# 211       Pattern Recognition and Machine Intelligence
# 212                                            DECLARE
# 213  2020 1st International Conference on Big Data ...
# 214                                               RAIL
# 215  2021 IEEE/CVF Conference on Computer Vision an...
# 216  IEEE International Conference on Formal Engine...
# 217           Machines, Computations, and Universality
# 218                                     JEPTALNRECITAL
# 219  2017 Pattern Recognition Association of South ...
# 220                                         PRIVATENLP
# 221                                             HCINLP
# 222                                            LORESMT
# 223      International Workshop on Semantic Evaluation
# 224                                                ACT
# 225  Finite-State Methods and Natural Language Proc...
# 226  International Conference on Principles of Know...
# 227  The 6th International Conference on Soft Compu...
# 228  International Conference on Natural Language P...
# 229           Theory and Practice of Logic Programming
# 230                                            HUMEVAL
# 231  International Conference on Software Engineeri...
# 232  International Conference on Machine Learning a...
# 233                                   Computer Science
# 234  Workshop on Balto-Slavic Natural Language Proc...
# 235                                             ALTNLP
# 236                                           BANGLALP
# 237  BlackboxNLP Workshop on Analyzing and Interpre...
# 238   International Conference on Software Engineering
# 239  China National Conference on Chinese Computati...
# 240  2019 Artificial Intelligence for Transforming ...
# 241     Applied Natural Language Processing Conference
# 242                                          Visual ..
# 243      Clinical Natural Language Processing Workshop
# 244                                               Fire
# 245                                           TRUSTNLP
# 246                BigData Congress [Services Society]
# 247            Lecture Notes in Electrical Engineering
# 248     Recent Advances in Natural Language Processing
# 249  International Workshop on Trustworthy AI - Int...
# 250                  Language Resources and Evaluation
# 251                                   Applied Sciences
# 252                               AAAI Spring Symposia
# 253  International Conference on Computational Proc...
# 254                                  Natural Computing
# 255  International Conference on Advances in ICT fo...
# 256                                        Rep4NLP@ACL
# 257                          Multilingual Facilitation
# 258                        Pattern Recognition Letters
# 259  IFIP TC13 International Conference on Human-Co...
# 260  Conference on Computational Natural Language L...
# 261  Romanian Conference on Human-Computer Interaction
# 262                                        Interspeech
# 263                        Nature Machine Intelligence
# 264  Computational Linguistics and Intellectual Tec...
# 265  IEEE International Geoscience and Remote Sensi...
# 266  International Journal for Research in Applied ...
# 267  2023 9th International Conference on Web Resea...
# 268                                   The VLDB journal
# 269                                          xxAI@ICML
# 270                                  E2ECOMPVEC@ESSLLI
# 271  ACM Transactions on Interactive Intelligent Sy...
# 272  International Journal of Prognostics and Healt...
# 273  Transactions of the Association for Computatio...
# 274                                              SLTAT
# 275                                          SUSTAINLP
# 276  APSIPA Transactions on Signal and Information ...
# 277   Deutsche Jahrestagung für Künstliche Intelligenz
# 278                                        FESCA@ETAPS
# 279                      Computers in industry (Print)
# 280               Frontiers in Artificial Intelligence
# 281               IEEE Robotics and Automation Letters
# 282  International Joint Conference on Computationa...
# 283                                        EthNLP@EACL
# 284                      Journal of New Music Research
# 285         IEEE Transactions on Human-Machine Systems
# 286                                    Artificial Life
# 287                 IEEE Vehicular Technology Magazine
# 288                                         Algorithms
# 289                                           iScience
# 290  The international journal of intelligence and ...
# 291  Mexican International Conference on Artificial...
# 292                                      Biotechnology
# 293                                              SIGAI
# 294                          Communications of the ACM
# 295                    Applied Artificial Intelligence
# 296                                               ARES
# 297                                 Front. Neurorobot.
# 298                     Int. J. Comput. Games Technol.
# 299                                        SafeAI@AAAI
# 300                   Swiss Conference on Data Science
# 301                                            Futures
# 302  Conference on Fairness, Accountability and Tra...
# 303     ACM Journal on Computing and Cultural Heritage
# 304                               Traitement du signal
# 305                                  Health technology
# 306          IEEE Communications Surveys and Tutorials
# 307                                 Minds and Machines
# 308            2021 IEEE World AI IoT Congress (AIIoT)
# 309                              Robotics Auton. Syst.
# 310  2019 Conference on Cognitive Computational Neu...
# 311                                 Electronic Markets
# 312  Journal of Artificial Intelligence and Conscio...
# 313  Aoristo. International journal of phenomenolog...
# 314                                 Information Fusion
# 315  International Workshop on Soft Computing Appli...
# 316  Journal of experimental and theoretical artifi...
# 317  Artificial Intelligence, Evolutionary Computin...
# 318  IEEE Transactions on Cognitive and Development...
# 319  European Conference on Logics in Artificial In...
# 320  Conference on Uncertainty in Artificial Intell...
# 321                            Artif. Intell. Medicine
# 322                                    The AI Magazine
# 323  International Workshop on Artificial Intellige...
# 324          IEEE Congress on Evolutionary Computation
# 325  Artificial Intelligence and Interactive Digita...
# 326  International Conference on Information Techno...
# 327                       Serdica Journal of Computing
# 328                                               NAIS
# 329  Proceedings of the 2019 International Conferen...
# 330                        Annals of Surgical Oncology
# 331   Journal of Information Security and Applications
# 332  2021 IEEE International Conference on Artifici...
# 333  Proceedings of the Thirtieth International Joi...
# 334        ACM Conference on Economics and Computation
# 335  International Conference on Artificial Intelli...
# 336                                           Synthese
# 337   Latin American Symposium on Circuits and Systems
# 338                                     The biochemist
# 339         Journal of Artificial General Intelligence
# 340     AAAI/ACM Conference on AI, Ethics, and Society
# 341  Proceedings of the 1st International Conferenc...
# 342             Neuro-Symbolic Artificial Intelligence
# 343                                    Future Internet
# 344  2022 IEEE 30th International Requirements Engi...
# 345                    Teorie vědy / Theory of Science
# 346  International Conference on Automated Software...
# 347                                 IEEE design & test
# 348  IIAI International Conference on Advanced Appl...
# 349                                      Reasoning Web
# 350                     Innovation (Cambridge (Mass.))
# 351                              Intelligent Computing
# 352  Sixth International Conference of Information ...
# 353    Frontiers in Applied Mathematics and Statistics
# 354                            Survey of ophthalmology
# 355                                            Cancers
# 356  EUROMICRO Conference on Software Engineering a...
# 357  Artificial Intelligence, Soft Computing and Ap...
# 358                                 We Will Show Them!
# 359                                  IFAC-PapersOnLine
# 360                                     AISafety@IJCAI
# 361                                        Measurement
# 362  Australasian Conference on Artificial Intellig...
# 363     International Journal of Approximate Reasoning
# 364    Journal of Vibration Engineering & Technologies
# 365  International Journal of Geographical Informat...
# 366                      Scandinavian Conference on AI
# 367                      Frontiers of Computer Science
# 368  ACM SIGACT-SIGMOD-SIGART Symposium on Principl...
# 369                                       Algorithmica
# 370  International Workshop on Neural-Symbolic Lear...
# 371                      Journal of engineering design
# 372                                Journal of Big Data
# 373  IEEE Transactions on Visualization and Compute...
# 374                                EDBT/ICDT Workshops
# 375                                              WIESP
# 376                               Information Sciences
# 377  IEEE Transactions on Pattern Analysis and Mach...
# 378                                        DL4KGS@ESWC
# 379                                                SDM
# 380                              Proc. ACM Manag. Data
# 381                                  Big Data Research
# 382                                Semdeep/NLIWoD@ISWC
# 383  Journal of King Saud University: Computer and ...
# 384  2019 IEEE/CVF International Conference on Comp...
# 385                      Advanced Quantum Technologies
# 386                                PKDD/ECML Workshops
# 387  IEEE International Conference on Tools with Ar...
# 388         Biomedical Circuits and Systems Conference
# 389  International Workshop and International Works...
# 390  ACM Transactions on Knowledge Discovery from Data
# 391  IEEE Transactions on Computational Social Systems
# 392  IEEE International Joint Conference on Neural ...
# 393  International Conference on Algorithmic Learni...
# 394  2018 IEEE/CVF Conference on Computer Vision an...
# 395                                          AKBC@NIPS
# 396                              Cognitive Computation
# 397    Journal of Computational Science and Technology
# 398                                  Physical Review E
# 399          International Conference on Big Knowledge
# 400  International Conference on Advanced Data Mini...
# 401  Conference on Artificial Intelligence in Medic...
# 402                                             FINNLP
# 403  International Symposium on Intelligent Data An...
# 404                                   DART/FAIR@MICCAI
# 405                                  EuroMLSys@EuroSys
# 406                Data mining and knowledge discovery
# 407                          Machine-mediated learning
# 408     European Conference on Artificial Intelligence
# 409  International Joint Conference on Natural Lang...
# 410                                    ICDAR Workshops
# 411                                             LOG IN
# 412                                         DL4KG@ESWC
# 413    International Conference on Pattern Recognition
# 414          Conference on Natural Language Processing
# 415  International Conference of the Italian Associ...
# 416  International Conference on Artificial Neural ...
# 417                                        DALI@MICCAI
# 418                                      AEQUITAS@ECAI
# 419  Pacific-Asia Conference on Knowledge Discovery...
# 420                                           SDU@AAAI
# 421                                       SemDeep@IWCS
# 422  International Conference on Service Oriented C...
# 423      Electronic Commerce Research and Applications
# 424              IEEE Transactions on Image Processing
# 425  2021 IEEE 23rd Int Conf on High Performance Co...
#
#                                            Journal_Ref   venueType  \
# 0                                                  NaN     journal
# 1                                                  NaN  conference
# 2    4th China Conference on Knowledge Graph and Se...  conference
# 3                                                  NaN  conference
# 4    Artificial Intelligence Supported Educational ...     journal
# 5                                                  NaN  conference
# 6                                                  NaN     journal
# 7                                                  NaN  conference
# 8                                                  NaN  conference
# 9                                                  NaN     journal
# 10                                                 NaN  conference
# 11                                                 NaN     journal
# 12                                                 NaN  conference
# 13                                                 NaN  conference
# 14                                                 NaN  conference
# 15                                                 NaN     journal
# 16                                                 NaN     journal
# 17                                                 NaN  conference
# 18                                                 NaN  conference
# 19                                                 NaN     journal
# 20                                                 NaN     journal
# 21                                                 NaN  conference
# 22                                                 NaN  conference
# 23                                                 NaN  conference
# 24                                                 NaN  conference
# 25                                                 NaN  conference
# 26                                                 NaN  conference
# 27                                                 NaN  conference
# 28                                                 NaN  conference
# 29                                                 NaN  conference
# 30                                                 NaN     journal
# 31                                                 NaN  conference
# 32                                                 NaN     journal
# 33                                                 NaN     journal
# 34   Knowledge and information Systems 62 (2020): 1...     journal
# 35   IEEE Transactions on Neural Networks and Learn...     journal
# 36                                                 NaN  conference
# 37                                                 NaN     journal
# 38                                                 NaN  conference
# 39                                                 NaN     journal
# 40                                                 NaN    workshop
# 41                                                 NaN  conference
# 42                                                 NaN     journal
# 43                                                 NaN  conference
# 44                                                 NaN     journal
# 45                                                 NaN  conference
# 46                                                 NaN  conference
# 47                                                 NaN     journal
# 48                                                 NaN  conference
# 49            Patterns Volume 3, Issue 5 (2022) 100484     journal
# 50                                                 NaN  conference
# 51                                                 NaN  conference
# 52                                                 NaN  conference
# 53   International Conference on Theory and Practic...  conference
# 54                                                 NaN  conference
# 55                                                 NaN     journal
# 56                                                 NaN    workshop
# 57                                                 NaN    workshop
# 58                                                 NaN  conference
# 59                                                 NaN     journal
# 60                                                 NaN  conference
# 61                                                 NaN     journal
# 62                                                 NaN     journal
# 63                                                 NaN  conference
# 64                                                 NaN  conference
# 65   IEEE TRANSACTIONS ON INTELLIGENT TRANSPORTATIO...     journal
# 66                                                 NaN     journal
# 67                                                 NaN     journal
# 68                                                 NaN     journal
# 69                                                 NaN  conference
# 70   AAAI Spring Symposium on Combining Machine Lea...     journal
# 71                                                 NaN     journal
# 72                                                 NaN     journal
# 73                                                 NaN     journal
# 74                                                 NaN     journal
# 75                                                 NaN  conference
# 76                                                 NaN     journal
# 77   ACM Transactions on Privacy and Security, Vol....     journal
# 78   The 26th International Conference on Computer ...  conference
# 79                                                 NaN     journal
# 80                                                 NaN  conference
# 81                                                 NaN     journal
# 82                                                 NaN    workshop
# 83                                                 NaN     journal
# 84   Intelligent Automation & Soft Computing, vol. ...     journal
# 85                    JMIR Med Inform 2020;8(5):e17645     journal
# 86   IEEE Transactions on Artificial Intelligence (...     journal
# 87                                                 NaN     journal
# 88                     DASFAA-2022: Overall Best Paper  conference
# 89                                                 NaN  conference
# 90                                                 NaN  conference
# 91                                                 NaN     journal
# 92                                                 NaN     journal
# 93                                                 NaN     journal
# 94                                                 NaN     journal
# 95                                                 NaN  conference
# 96                                                 NaN     journal
# 97                                                 NaN     journal
# 98                                                 NaN     journal
# 99                                                 NaN    workshop
# 100                                                NaN     journal
# 101                                                NaN     journal
# 102                                                NaN     journal
# 103                                                NaN  conference
# 104                         Cybersecurity 4, 31 (2021)     journal
# 105                                                NaN  conference
# 106                                                NaN    workshop
# 107                                                NaN     journal
# 108                                                NaN  conference
# 109                                                NaN     journal
# 110                                                NaN  conference
# 111                                                NaN  conference
# 112                                                NaN  conference
# 113                                                NaN     journal
# 114                                                NaN  conference
# 115                                                NaN  conference
# 116                                                NaN     journal
# 117                                                NaN  conference
# 118                                                NaN  conference
# 119                                                NaN     journal
# 120                                                NaN  conference
# 121                                                NaN     journal
# 122                                                NaN     journal
# 123                                                NaN     journal
# 124                                                NaN  conference
# 125                                                NaN     journal
# 126                                                NaN     journal
# 127                                                NaN     journal
# 128                                                NaN     journal
# 129                                                NaN  conference
# 130                                                NaN  conference
# 131                                                NaN  conference
# 132                                                NaN  conference
# 133                                                NaN  conference
# 134                                                NaN  conference
# 135                                                NaN     journal
# 136                                                NaN  conference
# 137                                                NaN     journal
# 138                                                NaN     journal
# 139                                                NaN  conference
# 140  2017 IEEE International Conference on Big Data...  conference
# 141                                                NaN     journal
# 142          Foundations and Trends in Databases, 2021     journal
# 143  Proceedings of the 2020 Federated Conference o...  conference
# 144                                                NaN     journal
# 145                                                NaN  conference
# 146                                                NaN     journal
# 147                                                NaN     journal
# 148                                                NaN     journal
# 149                                                NaN     journal
# 150                                                NaN     journal
# 151                                                NaN     journal
# 152  The 7th International Conference on Informatio...  conference
# 153                                                NaN     journal
# 154  Annual Review of Biomedical Data Science. 2020...     journal
# 155                                                NaN     journal
# 156                                                NaN  conference
# 157                                                NaN     journal
# 158                                                NaN     journal
# 159                                                NaN     journal
# 160                                                NaN  conference
# 161                                                NaN     journal
# 162                                                NaN  conference
# 163                                                NaN     journal
# 164                                                NaN     journal
# 165                                                NaN     journal
# 166                                                NaN     journal
# 167                                                NaN     journal
# 168                                                NaN     journal
# 169                                                NaN     journal
# 170                          Computing Conference 2021     journal
# 171                                                NaN     journal
# 172                                                NaN     journal
# 173                                                NaN  conference
# 174                                                NaN  conference
# 175  The International Conference on Artificial Int...  conference
# 176                                                NaN  conference
# 177                                                NaN  conference
# 178                                                NaN  conference
# 179                                                NaN     journal
# 180                                                NaN  conference
# 181                                                NaN     journal
# 182                                                NaN     journal
# 183                         EPTCS 283, 2018, pp. 13-27     journal
# 184  Information Processing Letters, Vol.113, pp.11...     journal
# 185                                                NaN  conference
# 186                                                NaN     journal
# 187                                                NaN     journal
# 188                                                NaN  conference
# 189                                                NaN     journal
# 190                                                NaN     journal
# 191                                                NaN     journal
# 192                         Multimed Tools Appl (2022)     journal
# 193                                                NaN     journal
# 194                                                NaN     journal
# 195  Proceedings of the 20th Conference ITAT 2020: ...  conference
# 196   Physics of Life Reviews, v. 11, p. 641-643, 2014     journal
# 197                                                NaN     journal
# 198                                                NaN    workshop
# 199                                                NaN     journal
# 200                                                NaN     journal
# 201                                                NaN    workshop
# 202                                                NaN     journal
# 203                                                NaN     journal
# 204  6th International Conference on Natural Langua...     journal
# 205                                                NaN  conference
# 206                                                NaN  conference
# 207  International Journal on Natural Language Comp...     journal
# 208  Information Processing & Management, Volume 60...     journal
# 209                                                NaN  conference
# 210  Proc. Int'l Workshop on Parsing Technologies, ...  conference
# 211                                                NaN     journal
# 212                                                NaN     journal
# 213                                                NaN  conference
# 214                                                NaN     journal
# 215  2021 IEEE/CVF Conference on Computer Vision an...  conference
# 216                                                NaN  conference
# 217                                                NaN     journal
# 218                                                NaN     journal
# 219                                                NaN     journal
# 220                                                NaN     journal
# 221                                                NaN     journal
# 222                                                NaN     journal
# 223                                                NaN    workshop
# 224                       EPTCS 333, 2021, pp. 311-321     journal
# 225                                                NaN     journal
# 226                                                NaN  conference
# 227  The 6th International Conference on Soft Compu...  conference
# 228                                                NaN  conference
# 229                                                NaN     journal
# 230                                                NaN     journal
# 231                                                NaN  conference
# 232                                                NaN  conference
# 233                     (2023) Computer Science, 24(2)     journal
# 234                                                NaN    workshop
# 235                                                NaN     journal
# 236                                                NaN     journal
# 237                                                NaN    workshop
# 238                                                NaN  conference
# 239                                                NaN  conference
# 240                                                NaN     journal
# 241                     ANLP'00, Seattle, WA, May 2000  conference
# 242                                                NaN     journal
# 243  In Proceedings of the 3rd Clinical Natural Lan...    workshop
# 244                                                NaN     journal
# 245  Proceedings of the 3rd Workshop on Trustworthy...     journal
# 246                                                NaN     journal
# 247                                                NaN     journal
# 248                                                NaN     journal
# 249                                                NaN    workshop
# 250                                                NaN     journal
# 251                          Appl. Sci. 2023, 13, 4758     journal
# 252                                                NaN     journal
# 253  Computational Processing of the Portuguese Lan...  conference
# 254                Natural Computing 20, 321-327, 2019     journal
# 255                                                NaN  conference
# 256                                                NaN     journal
# 257                                                NaN     journal
# 258     Pattern Recognition Letters 136 (2020) 120-126     journal
# 259                                                NaN  conference
# 260                                                NaN  conference
# 261                                                NaN  conference
# 262                                                NaN     journal
# 263                 Nature Machine Intelligence (2023)     journal
# 264                                                NaN     journal
# 265                                                NaN     journal
# 266                                                NaN     journal
# 267                                                NaN  conference
# 268                                                NaN     journal
# 269                                                NaN     journal
# 270                         EPTCS 366, 2022, pp. 23-34     journal
# 271                                                NaN     journal
# 272                                                NaN     journal
# 273                                                NaN     journal
# 274                                                NaN     journal
# 275                                                NaN     journal
# 276  APSIPA Transactions on Signal and Information ...     journal
# 277                                                NaN     journal
# 278                         EPTCS 205, 2016, pp. 59-68     journal
# 279                                                NaN     journal
# 280                                                NaN     journal
# 281                                                NaN     journal
# 282                                                NaN  conference
# 283                                                NaN     journal
# 284               Journal of New Music Research (2018)     journal
# 285    IEEE Transactions on Human-Machine Systems 2021     journal
# 286  Artificial Life, July 2023, Pages 1-35, Online...     journal
# 287                                                NaN     journal
# 288               Algorithms, 3:2 (2009) pages 879-906     journal
# 289                                                NaN     journal
# 290                                                NaN     journal
# 291  MICAI 2000: Advances in Artificial Intelligenc...  conference
# 292  Handbook of Research on Computational Intellig...     journal
# 293                 AI Matters 3(4):23-31, Winter 2018     journal
# 294                                                NaN     journal
# 295                                                NaN     journal
# 296  The 15th International ARES Conference on Avai...  conference
# 297                     Front Neurorobot. 2018; 12: 49     journal
# 298  International Journal of Computer Games Techno...     journal
# 299                                                NaN     journal
# 300  6th Swiss Conference on Data Science (SDS), Be...  conference
# 301                                                NaN     journal
# 302                                                NaN  conference
# 303                                                NaN     journal
# 304  Traitement du Signal, Vol. 39, No. 3, pp. 863-...     journal
# 305            Heal. Technol. 2022, pp. 1.7, Aug. 2022     journal
# 306       IEEE Communications Surveys & Tutorials,2022     journal
# 307        Minds and Machine, num 19, pp 319-343, 2009     journal
# 308                                                NaN     journal
# 309                                                NaN     journal
# 310                                                NaN  conference
# 311                                                NaN     journal
# 312  Journal of Artificial Intelligence and Conscio...     journal
# 313  Aoristo - International Journal of Phenomenolo...     journal
# 314                                                NaN     journal
# 315                                                NaN    workshop
# 316                                                NaN     journal
# 317  'Artificial Intelligence, Evolutionary Computa...     journal
# 318  IEEE Transactions on Cognitive and Development...     journal
# 319  In: J. Dix, L. Farinas del Cerro, and U. Furba...  conference
# 320  Journal of Artificial Intelligence Research 26...  conference
# 321  Artificial Intelligence in Medicine 3, 2 (1991...     journal
# 322                            AI Magazine 36:4 (2015)     journal
# 323  Proceedings of the 4th International Workshop ...    workshop
# 324                                                NaN     journal
# 325                                                NaN  conference
# 326                                                NaN  conference
# 327  Serdica Journal of Computing, Vol. 13, Number ...     journal
# 328                                                NaN     journal
# 329                                                NaN  conference
# 330                                                NaN     journal
# 331                                                NaN     journal
# 332  2021 IEEE International Conference on Artifici...  conference
# 333                                                NaN  conference
# 334                                                NaN  conference
# 335  International Conference on Artificial Intelli...  conference
# 336                                                NaN     journal
# 337  @proceedings{liang2019logistic, title = {Proce...     journal
# 338                                                NaN     journal
# 339  Journal of Artificial General Intelligence 11(...     journal
# 340                                                NaN  conference
# 341                                                NaN  conference
# 342                                                NaN     journal
# 343                                                NaN     journal
# 344                                                NaN  conference
# 345  Teorie V\\v{e}dy / Theory of Science, 1(1), Ar...     journal
# 346                                                NaN  conference
# 347                                                NaN     journal
# 348                                                NaN  conference
# 349                                                NaN     journal
# 350                                                NaN     journal
# 351                        Intell. Comput. 2023;2:0006     journal
# 352  in Proceedings of the Sixth International Conf...  conference
# 353                  Front. Appl. Math. Stat. 7 (2021)     journal
# 354                                                NaN     journal
# 355  2023 Third International Conference on Advance...     journal
# 356                                                NaN  conference
# 357                                                NaN  conference
# 358                                                NaN     journal
# 359                                                NaN     journal
# 360                                                NaN     journal
# 361                                                NaN     journal
# 362  Proc. 25th Australasian Joint Conference on Ar...  conference
# 363                                                NaN     journal
# 364                                                NaN     journal
# 365                                                NaN     journal
# 366                                                NaN  conference
# 367                                                NaN     journal
# 368                                                NaN     journal
# 369                                                NaN     journal
# 370                                                NaN    workshop
# 371                                                NaN     journal
# 372                                                NaN     journal
# 373                                                NaN     journal
# 374    Data Science for Industry 4.0 at EDBT/ICDT 2019    workshop
# 375                                                NaN     journal
# 376                                                NaN     journal
# 377                                                NaN     journal
# 378                                                NaN     journal
# 379                                                NaN  conference
# 380                                                NaN     journal
# 381                                                NaN     journal
# 382                                                NaN     journal
# 383                                                NaN     journal
# 384                                                NaN  conference
# 385                Advanced Quantum Technologies, 2019     journal
# 386                                                NaN    workshop
# 387                                                NaN  conference
# 388                                                NaN  conference
# 389                                                NaN    workshop
# 390                                                NaN     journal
# 391                                                NaN     journal
# 392                                                NaN  conference
# 393                                                NaN  conference
# 394                                                NaN  conference
# 395                                                NaN     journal
# 396                                                NaN     journal
# 397                                                NaN     journal
# 398                                                NaN     journal
# 399                                                NaN  conference
# 400                                                NaN  conference
# 401                                                NaN  conference
# 402                                                NaN     journal
# 403  Full paper at the Symposium on Intelligent Dat...     journal
# 404                                                NaN     journal
# 405                                                NaN     journal
# 406                                                NaN     journal
# 407                                                NaN     journal
# 408  Proceedings of the European Conference on Arti...  conference
# 409                                                NaN  conference
# 410                                                NaN    workshop
# 411                                                NaN     journal
# 412                                                NaN     journal
# 413                                                NaN  conference
# 414                                                NaN  conference
# 415                                                NaN  conference
# 416                                                NaN  conference
# 417                                                NaN     journal
# 418                                                NaN     journal
# 419                                                NaN  conference
# 420                                                NaN     journal
# 421                                                NaN     journal
# 422                                                NaN  conference
# 423  Electronic Commerce Research and Applications ...     journal
# 424                                                NaN     journal
# 425                                                NaN     journal
#
#     impactFactor
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# 5           None
# 6           None
# 7           None
# 8           None
# 9           None
# 10          None
# 11          None
# 12          None
# 13          None
# 14          None
# 15          None
# 16          None
# 17          None
# 18          None
# 19          None
# 20          None
# 21          None
# 22          None
# 23          None
# 24          None
# 25          None
# 26          None
# 27          None
# 28          None
# 29          None
# 30          None
# 31          None
# 32          None
# 33          None
# 34          None
# 35          None
# 36          None
# 37          None
# 38          None
# 39          None
# 40          None
# 41          None
# 42          None
# 43          None
# 44          None
# 45          None
# 46          None
# 47          None
# 48          None
# 49          None
# 50          None
# 51          None
# 52          None
# 53          None
# 54          None
# 55          None
# 56          None
# 57          None
# 58          None
# 59          None
# 60          None
# 61          None
# 62          None
# 63          None
# 64          None
# 65          None
# 66          None
# 67          None
# 68          None
# 69          None
# 70          None
# 71          None
# 72          None
# 73          None
# 74          None
# 75          None
# 76          None
# 77          None
# 78          None
# 79          None
# 80          None
# 81          None
# 82          None
# 83          None
# 84          None
# 85          None
# 86          None
# 87          None
# 88          None
# 89          None
# 90          None
# 91          None
# 92          None
# 93          None
# 94          None
# 95          None
# 96          None
# 97          None
# 98          None
# 99          None
# 100         None
# 101         None
# 102         None
# 103         None
# 104         None
# 105         None
# 106         None
# 107         None
# 108         None
# 109         None
# 110         None
# 111         None
# 112         None
# 113         None
# 114         None
# 115         None
# 116         None
# 117         None
# 118         None
# 119         None
# 120         None
# 121         None
# 122         None
# 123         None
# 124         None
# 125         None
# 126         None
# 127         None
# 128         None
# 129         None
# 130         None
# 131         None
# 132         None
# 133         None
# 134         None
# 135         None
# 136         None
# 137         None
# 138         None
# 139         None
# 140         None
# 141         None
# 142         None
# 143         None
# 144         None
# 145         None
# 146         None
# 147         None
# 148         None
# 149         None
# 150         None
# 151         None
# 152         None
# 153         None
# 154         None
# 155         None
# 156         None
# 157         None
# 158         None
# 159         None
# 160         None
# 161         None
# 162         None
# 163         None
# 164         None
# 165         None
# 166         None
# 167         None
# 168         None
# 169         None
# 170         None
# 171         None
# 172         None
# 173         None
# 174         None
# 175         None
# 176         None
# 177         None
# 178         None
# 179         None
# 180         None
# 181         None
# 182         None
# 183         None
# 184         None
# 185         None
# 186         None
# 187         None
# 188         None
# 189         None
# 190         None
# 191         None
# 192         None
# 193         None
# 194         None
# 195         None
# 196         None
# 197         None
# 198         None
# 199         None
# 200         None
# 201         None
# 202         None
# 203         None
# 204         None
# 205         None
# 206         None
# 207         None
# 208         None
# 209         None
# 210         None
# 211         None
# 212         None
# 213         None
# 214         None
# 215         None
# 216         None
# 217         None
# 218         None
# 219         None
# 220         None
# 221         None
# 222         None
# 223         None
# 224         None
# 225         None
# 226         None
# 227         None
# 228         None
# 229         None
# 230         None
# 231         None
# 232         None
# 233         None
# 234         None
# 235         None
# 236         None
# 237         None
# 238         None
# 239         None
# 240         None
# 241         None
# 242         None
# 243         None
# 244         None
# 245         None
# 246         None
# 247         None
# 248         None
# 249         None
# 250         None
# 251         None
# 252         None
# 253         None
# 254         None
# 255         None
# 256         None
# 257         None
# 258         None
# 259         None
# 260         None
# 261         None
# 262         None
# 263         None
# 264         None
# 265         None
# 266         None
# 267         None
# 268         None
# 269         None
# 270         None
# 271         None
# 272         None
# 273         None
# 274         None
# 275         None
# 276         None
# 277         None
# 278         None
# 279         None
# 280         None
# 281         None
# 282         None
# 283         None
# 284         None
# 285         None
# 286         None
# 287         None
# 288         None
# 289         None
# 290         None
# 291         None
# 292         None
# 293         None
# 294         None
# 295         None
# 296         None
# 297         None
# 298         None
# 299         None
# 300         None
# 301         None
# 302         None
# 303         None
# 304         None
# 305         None
# 306         None
# 307         None
# 308         None
# 309         None
# 310         None
# 311         None
# 312         None
# 313         None
# 314         None
# 315         None
# 316         None
# 317         None
# 318         None
# 319         None
# 320         None
# 321         None
# 322         None
# 323         None
# 324         None
# 325         None
# 326         None
# 327         None
# 328         None
# 329         None
# 330         None
# 331         None
# 332         None
# 333         None
# 334         None
# 335         None
# 336         None
# 337         None
# 338         None
# 339         None
# 340         None
# 341         None
# 342         None
# 343         None
# 344         None
# 345         None
# 346         None
# 347         None
# 348         None
# 349         None
# 350         None
# 351         None
# 352         None
# 353         None
# 354         None
# 355         None
# 356         None
# 357         None
# 358         None
# 359         None
# 360         None
# 361         None
# 362         None
# 363         None
# 364         None
# 365         None
# 366         None
# 367         None
# 368         None
# 369         None
# 370         None
# 371         None
# 372         None
# 373         None
# 374         None
# 375         None
# 376         None
# 377         None
# 378         None
# 379         None
# 380         None
# 381         None
# 382         None
# 383         None
# 384         None
# 385         None
# 386         None
# 387         None
# 388         None
# 389         None
# 390         None
# 391         None
# 392         None
# 393         None
# 394         None
# 395         None
# 396         None
# 397         None
# 398         None
# 399         None
# 400         None
# 401         None
# 402         None
# 403         None
# 404         None
# 405         None
# 406         None
# 407         None
# 408         None
# 409         None
# 410         None
# 411         None
# 412         None
# 413         None
# 414         None
# 415         None
# 416         None
# 417         None
# 418         None
# 419         None
# 420         None
# 421         None
# 422         None
# 423         None
# 424         None
# 425         None

# %%
venue_df[["Venue","venueType"]].to_csv("venue_df.csv", sep=',')

# %% [markdown]
# **Keyword Dataframe**

# %%
keywords_final = list(set(keywords_final))

# %%
keyword_df = pd.DataFrame({'keywordName':keywords_final})

# %%
keyword_df.to_csv("keyword_df.csv", sep=',')

# %% [markdown]
# **VenueType Dataframe**

# %%
venueType_df = pd.DataFrame({
    "typeName" : ['Journal', 'Conference', 'arXiv','Workshop']
})

# %%
venueType_df.to_csv("venueType_df.csv", sep=',')

# %% [markdown]
# **hasKeyword Dataframe**

# %%
hasKeyword_df = df[["Paper_ID","Extracted_Keywords"]]
hasKeyword_df.head()
# Out:
#                                    Paper_ID  \
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 1  af063194baee08931f12facdffc573e4bd29c463
# 2  f2aca403781821618d7a69d98a9fbddccb236081
# 3  9921e8a2ed1d7ddaf6fdc6491d7cea321073c0b3
# 4  fb08c6d5f8fe80cfbd9efa75b710f326f4846a0f
#
#                                   Extracted_Keywords
# 0  [knowledge acquisition, graphs, knowledge grap...
# 1  [graphs, knowledge, natural language, graph, k...
# 2  [graphs, knowledge, graph, knowledge graph, co...
# 3  [graphs, knowledge graph completion, knowledge...
# 4  [graphs, knowledge, graph, embedding, gan, kno...

# %%
# hasKeyword_df['Extracted_Keywords'] = hasKeyword_df['Extracted_Keywords'].apply(ast.literal_eval)

hasKeyword_df = hasKeyword_df.explode('Extracted_Keywords').reset_index(drop=True)

# %%
hasKeyword_df.head()
# Out:
#                                    Paper_ID          Extracted_Keywords
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d       knowledge acquisition
# 1  42b323b6df79e49c9bf5cee2a91398a7fa3d594d                      graphs
# 2  42b323b6df79e49c9bf5cee2a91398a7fa3d594d  knowledge graph completion
# 3  42b323b6df79e49c9bf5cee2a91398a7fa3d594d                   knowledge
# 4  42b323b6df79e49c9bf5cee2a91398a7fa3d594d  knowledge graph embeddings

# %%
hasKeyword_df.columns = ['paperID', 'keywordName']
hasKeyword_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10834 entries, 0 to 10833
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   paperID      10834 non-null  object
#  1   keywordName  10787 non-null  object
# dtypes: object(2)
# memory usage: 169.4+ KB

# %%
hasKeyword_df.dropna(subset=["keywordName"], inplace=True)

# %%
hasKeyword_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10787 entries, 0 to 10833
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   paperID      10787 non-null  object
#  1   keywordName  10787 non-null  object
# dtypes: object(2)
# memory usage: 252.8+ KB

# %%
hasKeyword_df.reset_index(drop=True, inplace=True)
hasKeyword_df.to_csv("hasKeyword_df.csv", sep=',')

# %% [markdown]
# **publishedIn Dataframe**

# %%
df.columns
# Out:
# Index(['Paper_ID', 'Title', 'Summary', 'Published_Date', 'Updated_Date',
#        'PDF_URL', 'DOI', 'Journal_Ref', 'Primary_Category', 'Categories',
#        'Comments', 'Full_Text', 'Citation_Count', 'References', 'Venue',
#        'Keywords', 'Authors_sccho', 'Keyword_semi', 'Keywords_cleaned',
#        'Keywords_list', 'Extracted_Keywords'],
#       dtype='object')

# %%
publishedIn_df = df[["Paper_ID", "Venue"]]
publishedIn_df.head()
# Out:
#                                    Paper_ID  \
# 0  42b323b6df79e49c9bf5cee2a91398a7fa3d594d
# 1  af063194baee08931f12facdffc573e4bd29c463
# 2  f2aca403781821618d7a69d98a9fbddccb236081
# 3  9921e8a2ed1d7ddaf6fdc6491d7cea321073c0b3
# 4  fb08c6d5f8fe80cfbd9efa75b710f326f4846a0f
#
#                                                Venue
# 0                     Artificial Intelligence Review
# 1  Conference on Human Information Interaction an...
# 2  China Conference on Knowledge Graph and Semant...
# 3                    J. Parallel Distributed Comput.
# 4    Advances in Analytics for Learning and Teaching

# %%
publishedIn_df.to_csv("publishedIn_df.csv", sep=',')

# %% [markdown]
# **Venue Dataframe and hasType Dataframe**

# %%
venue_type_df = pd.read_csv("venue_df.csv", index_col=0)
venue_type_df.head()
# Out:
#                                                Venue   venueType;;;
# 0                     Artificial Intelligence Review     journal;;;
# 1  Conference on Human Information Interaction an...  conference;;;
# 2  China Conference on Knowledge Graph and Semant...  conference;;;
# 3                    J. Parallel Distributed Comput.     journal;;;
# 4    Advances in Analytics for Learning and Teaching     journal;;;

# %%
venue_type_df.drop_duplicates(subset=['Venue'],inplace=True)

# %%
venue_type_df.reset_index(drop=True, inplace=True)

# %%
venue_type_df.shape
# Out:
# (405, 2)

# %%
venue_df = venue_type_df[["Venue"]]
venue_df.columns=['venueName']
venue_df.head()
# Out:
#                                            venueName
# 0                     Artificial Intelligence Review
# 1  Conference on Human Information Interaction an...
# 2  China Conference on Knowledge Graph and Semant...
# 3                    J. Parallel Distributed Comput.
# 4    Advances in Analytics for Learning and Teaching

# %%
venue_df.to_csv('venue_df.csv', sep=',')

# %%
venueType_df = venue_type_df.copy()

venueType_df.head()
# Out:
#                                                Venue   venueType;;;
# 0                     Artificial Intelligence Review     journal;;;
# 1  Conference on Human Information Interaction an...  conference;;;
# 2  China Conference on Knowledge Graph and Semant...  conference;;;
# 3                    J. Parallel Distributed Comput.     journal;;;
# 4    Advances in Analytics for Learning and Teaching     journal;;;

# %%
venueType_df.columns = ['venueName','typeName']
venueType_df['typeName'] = venueType_df['typeName'].str.replace(";","")
venueType_df.head()
# Out:
#                                            venueName    typeName
# 0                     Artificial Intelligence Review     journal
# 1  Conference on Human Information Interaction an...  conference
# 2  China Conference on Knowledge Graph and Semant...  conference
# 3                    J. Parallel Distributed Comput.     journal
# 4    Advances in Analytics for Learning and Teaching     journal

# %%
venueType_df.to_csv("hasType_df.csv",sep=',')
